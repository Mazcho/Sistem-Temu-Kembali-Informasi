# %% [markdown]
# Preprocesing Text menggunakan NLTK

# %% [markdown]
# Nicholaus Verdhy || A11.2020.12447

# %% [markdown]
# # Penjelasan Singkat mengenai NLTK

# %% [markdown]
# NLTK adalah kumpulan alat dan program yang digunakan untuk memproses dan menganalisis bahasa alami (NLP) dalam bahasa Inggris. Ini ditulis dalam bahasa pemrograman Python dan digunakan untuk tugas-tugas NLP yang melibatkan analisis teks dan statistik[1]

# %% [markdown]
# # Project 1 : Preprocessing dengan NLTK

# %% [markdown]
# ## Import Library

# %%
import re
import string
import time
import pandas as pd
from copy import deepcopy


#Untuk Preprocessing Data nya
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

#import nltk
import nltk
from nltk.tokenize import word_tokenize

#ignore warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Penjelasan untuk setiap library
# - `import re` digunakan untuk bekerja dengan ekspresi reguler (regular expressions), yang memungkinkan Anda untuk melakukan pencarian dan manipulasi teks berdasarkan pola-pola tertentu.digunakan untuk pencarian dan manipulasi teks berdasarkan pola pola tertentu
# - `import string` digunakan dalam manipulasi teks, seperti menghapus tanda baca atau mengoperasikan karakter-karakter tertentu
# - `import time` digunakan untuk bekerja dengan waktu dan tanggal dalam Python.
# - `import pandas` digunakan untuk memuat dataset yang ada
# - `from copy import deepcopy`  ini gunanya, ketika kita melakukan duplikasi dari objek, maka hasil duplikasinya adalah objek baru dan tidak terpengaruhi oleh objek lama
# - `from ekphrasis.classes.preprocessor import TextPreProcessor` untuk melakukan berbagai tugas pemrosesan teks, terutama pada teks yang berasal dari media sosial.
# - `from ekphrasis.classes.tokenizer import SocialTokenizer`adalah tokenizer yang digunakan untuk membagi teks menjadi kata-kata
# - `from ekphrasis.dicts.emoticons import emoticons` adalah kamus yang mungkin digunakan untuk mengganti emotikon dengan kata-kata yang sesuai.
# - `import nltk` adalah pernyataan impor untuk mengimpor modul NLTK (Natural Language Toolkit), yang merupakan pustaka yang digunakan dalam pemrosesan bahasa alami (NLP)
# - `from nltk.tokenize import word_tokenize` adalah salah satu alat dalam NLTK yang digunakan untuk membagi teks menjadi kata-kata atau token.
# - `import warning` mengabaikan warning

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv("Dataset_Sentimen_Emosi.csv")

# %%
df.head()
# Out:
#                                                Tweet  Sentimen  Emosi
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0     -2
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0     -2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     904 non-null    object
#  1   Sentimen  903 non-null    float64
#  2   Emosi     904 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 21.3+ KB

# %% [markdown]
# Deskripsi Kolom:
#
# `Tweet` : Isi hasil tweet orang di twiter
#
# `Sentimen`  : mengindikasikan sentimen atau perasaan yang terkait dengan setiap tweet. Sentimen dapat berupa positif, negatif, netral, atau mungkin memiliki label lebih rinci seperti senang, marah, sedih, dan lain-lain.
#
# `Emosi`      : sama seperti sentimen

# %% [markdown]
# ## Data Cleansing

# %% [markdown]
# Melakukan pengecekan missing value pada dataset yang ada

# %%
df.isna().sum()
# Out:
# Tweet       0
# Sentimen    1
# Emosi       0
# dtype: int64

# %% [markdown]
# Terdapat 1 data missing value pada kolom Sentimen, mari kita hapus dengan dropna

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Tweet       0
# Sentimen    0
# Emosi       0
# dtype: int64

# %% [markdown]
# Lalu kita menghapus kolom yang tidak dipakai

# %%
df.drop("Emosi",axis=1, inplace=True)

# %% [markdown]
# Data sudah bersih, kita lanjutkan pada tahap PreProcessingg data

# %%
# kita pidnahkan ke variabel baru
df_new = df.copy()

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# ### Modul Ekpharasis

# %% [markdown]
# Sumber modul : https://github.com/cbaziotis/ekphrasis

# %% [markdown]
# Modulnya ekphrasis

# %%
text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %% [markdown]
# PENJELASAN SINGKAT  TEXT_PROCESOR DARI EKPHARASIS

# %% [markdown]
# Jadi **`TextPreProcessor`** adalah pustaka dari Ekpharasis. TextPreProcessing ini digunakan untuk memproses teks dalam berbagai cara sesuai dengan konfigurasi yang telah ditentukan. Teks yang diambil biasanya diambil dari media sosial.

# %% [markdown]
# 1. `normalize` : ini adalah kata kata yang dinormalisasikan dalam teks. Yang nantinya mengubah kata kata/ frasa tertentu menjadi bentuk yang lebih umum. Misal di dalam kode kita ada email, percent, money, phoinoe dan linnya. jika kita memiliki kalimat " Nico mempuinyai email nicho@gmail.com dengan nomor hp 00000" maka akan dinormalisasikan menjadi : `<user>`Nicho`<user>` mempunyai email `<email>`nicho@gmail.com`<email>` dengan nomor hp `<phone>` 00000`<phone>` .
#
# 2. `annotate` : ini gunanya untuk mengubah bentuk yang diberi anotasi didalam kata/ kalimat. Anotasinya berupa  hastag (hastag), berupapengulaaaaaan (elonganted), KAPITALSMUA (allcaps), Woo woo woo (repeated), Amazing!!!!(Emphasis), F** and S**t (censored). hasil nya nanti seperti notmalize. Kata tersebut akan dinormalisasikan
#
# 3. `fix_html` : fix html ini digunakan perbaiakan token token html dalam teks.
#
# 4. `segmenter` dan `corrector` : segementer lebih untuk menyuruh ekpharasis untuk menggunakan korpus bahasa yang biasanya ada di twitter, lalu corrector melakukan koreksi ejaan yang bereferensikan dari twitter.
#
# 5. `unpack_hashtags=True` : Dengan pengaturan ini, Ekphrasis akan melakukan pemisahan kata pada hashtag. dari #contoh menjadi 'contoh'
#
# 6. `unpack_contractions=True` : Dengan pengaturan ini, Ekphrasis akan melakukan pemisahan pada kontraksi bahasa. Misalnya, kontraksi "can't" akan dipisahkan menjadi "can" dan "not."
#
# 7. `spell_correct_elong=False` : Jika diatur sebagai `True` , Ekphrasis akan melakukan koreksi ejaan pada kata-kata yang memiliki karakter pengulangan (seperti "sooo" menjadi "so"). Namun, dalam pengaturan ini (diatur sebagai False), koreksi ejaan untuk kata-kata yang diulang tidak akan dilakukan.
#
# 8. `tokenizer`: Ini adalah konfigurasi untuk pemilihan tokenizer yang digunakan dalam pemrosesan teks. Mmenggunakan SocialTokenizer dengan opsi `lowercase=True`. Tokenizer ini akan **memecah teks** menjadi sejumlah token berdasarkan **spasi**, dan semua token akan **dikonversi menjadi huruf kecil (lowercase)**.
#
# 9. `dicts=[emoticons]` : Ini adalah konfigurasi yang memungkinkan Anda untuk mengganti token dalam teks dengan ekspresi lain. Dalam pengaturan ini, emoticons digunakan sebagai kamus untuk mengganti emotikon dalam teks dengan ekspresi tertentu.

# %% [markdown]
# ### Pembuatan fungsi untuk PreProcessing

# %% [markdown]
# Selanjutnya kita akan membuat fungsin fungsi yang akan membantu kita dalam melakukan Prapreoses data dari dataset yang diberikan

# %%
#1. memanggil ekhparasis yang sudah dibuat
def pembersihan_data(text):
    return " ". join(text_processor.pre_process_doc(text))

#fungsi ams 1-3

#2. mengubah non ascii jadi ascii
def mengganti_non_ascii(text):
    return text.encode('ascii','replace').decode('ascii')

#3. menghapus spasi ekstra dalam teks
def menhapus_extra_spasi(text):
    return " ".join(text.split()) #dikembalikan menjadi single space, lalu dilakukan join pada text, lalu dilakukan split.

#4. Menghapus emoji/ emotikon
def menghapus_emoticon_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

#5. menghapus karakter tab (\t), baris baru (\n), dan karakter khusus
def hapus_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

#6. Menggantikan beberapa spasi berturut-turut dengan satu spasi tunggal
def ganti_spasi_tunggal(text):
    return re.sub('\s+',' ',text) # jadi jika pada kalimat itu terdapat tab baru, baris baru alan digantikan dengan " "

#7. Menghapus kata RT ( Retweet)
def hapus_ReTweet(text):
    return text.replace('RT'," ") # dari kata RT, di replace jadi kosong " "

#8 Hapus elemen elemen mention 
def hapus_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split()) #dari karaketer yang ada di replace menajadi white sapce, lalau di split

#9 hapus url
def hapus_url(text):
    return text.replace("http://", " ").replace("https://", " ") #akan menggantikan http:// dan htpps:// menjadi whitesapce

#10 hapus single karakter
def mnenghapus_single_karakter(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text) # jika ada karakter huruf yang tunggal atau tidak diapit hutuf lain akan dihapus

#11 hapus titik extra
def menghapus_titik_extra(text):
    return text.replace('..'," ") # menghapus extra ... yang berlebihan menjadi .

#12 mengahapus strip
def mengganti_strip(text):
    return text.replace('-'," ") #ketika ada kalimat mengadung -, maka akan direplace dengan whitespace " "

#13 Membuat smua huruf jadi kecil
def huruf_kecil_semua(text):
    return text.lower() #membuat semua teks menjadi huruf non kapital

#14. Menghapus spasi di awal kalimat dan ahkir kalimat
def hapus_spasi_awal_ahkir_kalimat(text):
    return text.strip() #jadi strip() gunanya untuk menghapus spasi depan dan blakang

#15. hapus Spasi berlebihan
def hapus_spasi_dobel(text):
    return re.sub('\s+',' ',text) #menahpus spasi yang berlebihan

#16. Mengapus tanda baca, kecuali tanda hubung
def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text) 

#17. hapus untuk <>
def hapus_number_eks(text):
    return text.replace('<number>'," ")
#18. hapus angka
def hapus_angka(text):
    return re.sub(r"\d+", "", text) 
#19. Hapus teks URL
def hapus_URL_teks(text):
    return text.replace('URL'," ").replace('url'," ") #jadi teks URL atau url jadi white sapce
#20. Pengaturan Spasi
def pengaturan_spasi(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text) #memberikan spasi sebelum tanda baca

# %% [markdown]
# Penjelasan kode :
#
# 1. `pembersihan_data(text)`: Menggunakan `text_processor` (yang telah diinisialisasi sebelumnya) untuk membersihkan dan memproses teks dokumen.
#
# 2. `mengganti_non_ascii(text)`: Menggantikan karakter non-ASCII dengan karakter yang sesuai dalam ASCII. Karakter non-ASCII akan digantikan dengan tanda tanya atau karakter lainnya sesuai aturan penggantian.
#
# 3. `menhapus_extra_spasi(text)`: Menghapus spasi ekstra dalam teks, menggantinya dengan satu spasi tunggal.
#
# 4. `menghapus_emoticon_emoji(text)`: Menghapus emotikon atau emoji dalam teks dengan menggantikannya dengan spasi.
#
# 5. `hapus_tab(text)`: Menghapus karakter tab (`\t`), baris baru (`\n`), dan karakter khusus lainnya dari teks.
#
# 6. `ganti_spasi_tunggal(text)`: Menggantikan beberapa spasi berturut-turut dengan satu spasi tunggal.
#
# 7. `hapus_ReTweet(text)`: Menghapus kata "RT" (Retweet) dari teks.
#
# 8. `hapus_mention(text)`: Menghapus elemen-elemen mention atau tag dalam teks, seperti "@username".
#
# 9. `hapus_url(text)`: Menghapus URL dari teks, baik yang dimulai dengan "http://" maupun "https://".
#
# 10. `mnenghapus_single_karakter(text)`: Menghapus karakter tunggal yang tidak diapit oleh huruf lain.
#
# 11. `menghapus_titik_extra(text)`: Menghapus tanda titik yang berlebihan dan menggantikannya dengan spasi.
#
# 12. `mengganti_strip(text)`: Menggantikan tanda strip (-) dengan spasi.
#
# 13. `huruf_kecil_semua(text)`: Mengubah semua huruf dalam teks menjadi huruf kecil.
#
# 14. `hapus_spasi_awal_ahkir_kalimat(text)`: Menghapus spasi di awal dan akhir kalimat.
#
# 15. `hapus_spasi_dobel(text)`: Menghapus spasi berlebihan dalam teks.
#
# 16. `remove_punctuation(text)`: Menghapus tanda baca, kecuali tanda hubung (-).
#
# 17. `hapus_number_eks(text)`: Menghapus teks "<number>".
#
# 18. `hapus_angka(text)`: Menghapus semua angka dalam teks.
#
# 19. `hapus_URL_teks(text)`: Menghapus teks "URL" atau "url".
#
# 20. `pengaturan_spasi(text)`: Menambahkan spasi sebelum tanda baca, menjaga spasi di antara kata-kata dan tanda baca.

# %% [markdown]
# Setelah membuat fungsi fungsi yang ada, kita melakukan prapreosesing datanya dengan fungsi yang telah kita buat

# %% [markdown]
# ### Penerapan PreProcessing dari fungsi

# %%
hasil_string = []

#mengambil kalimat yang ada dalam array twwet dengan values
for kalimat in df_new["Tweet"].values:    
    ulasan_teks=""
    #1. hapus RT 
    proses = hapus_ReTweet(kalimat)
    
    #2. proses mengubah elemen kalimat jadi kecil
    proses = huruf_kecil_semua(proses)
    
    #3. Setelah huruf smua kecil, menghapus yang berhubungan dengan link
    proses = hapus_URL_teks(proses)
    proses = hapus_url(proses)
    
    #4. Melakukan pembersihan data menggunakan fungsi dari ekpharasis
    proses = pembersihan_data(proses)
    
    #5. Menghapus Angka
    proses = hapus_number_eks(proses) #hapus <angka>
    proses = hapus_angka(proses)#hapus elemen angka
    
    #6 menghapus elemen tambahan sepertei baris, tab, emoticon
    proses = hapus_mention(proses)
    proses = menghapus_emoticon_emoji(proses)
    proses = menghapus_titik_extra(proses)
    proses = remove_punctuation(proses)
    proses = mnenghapus_single_karakter(proses)
    
    #6 Mengganti strip jadi white space
    proses = mengganti_strip(proses)
        
    #8 Menghapus Spasi dan pengaturan spasi
    proses = hapus_spasi_awal_ahkir_kalimat(proses) 
    proses = hapus_spasi_dobel(proses)
    proses = menhapus_extra_spasi(proses)
    proses = ganti_spasi_tunggal(proses)
    proses = pengaturan_spasi(proses)
    proses = hapus_tab(proses)
    

    #9 Penerapan ASCII
    proses = mengganti_non_ascii(proses)
    
    #Penyimpanan teks kedalam ulasan teks agar menjadi teks yang bisa diterima
    ulasan_teks = proses
    hasil_string.append(ulasan_teks)

# %%
#kita buat kolom baru namanya langkah01 dengan isinya hasil_string
df_new["langkah01"] = hasil_string

# %% [markdown]
# ### Hasil langkah01

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
#
#                                            langkah01
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jum at jum at keempat di kal...
# 7  hikmah di balik musibah covid smg para pejabat...
# 8  cegah covid beserta jajaran polsek kuranji mel...
# 9  ya allah kami memohon pada mu perkenankanlah d...

# %% [markdown]
# ### Melakukan Tokenisasi dengan NLTK

# %%
def melakukan_tokenization(text):
    return word_tokenize(text)

# %%
df_new["tokenisasi"] = df_new['langkah01'].apply(melakukan_tokenization) #melakukan fungsi diatas dengan apply tiap kolomnya

# %%
df_new.head()
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
#
#                                            langkah01  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
#
#                                           tokenisasi
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...

# %% [markdown]
# ### Mengubah **KATA TIDAK BAKU** jadi **KATA BAKU**

# %% [markdown]
# Proses berikutnya yaitu mengubah kata yanbg tidak baku menjadi baku menggunakan dataset kamus_clean.csv

# %%
#loading datasetnya
kamus_baku = pd.read_csv("kamus_clean.csv")

# %%
kamus_baku
# Out:
#        Unnamed: 0    TIDAK BAKU                               BAKU
# 0               0       mangtab                              bagus
# 1               1   evolusionis                       revolusioner
# 2               6      abstarck                            abstrak
# 3               7  sebenenarnya                         sebenarnya
# 4               8   kataakanlah                         katakanlah
# ...           ...           ...                                ...
# 15017       16016     mendikbud  menteri pendidikan dan kebudayaan
# 15018       16017        mendag                menteri perdagangan
# 15019       16018       menaker               menteri tenaga kerja
# 15020       16019      memetwit                            mentwit
# 15021       16020      megangin                           memegang
#
# [15022 rows x 3 columns]

# %% [markdown]
# Sekarang kita menggunakan perulangan untuk mengecek dan mengganti kata kata tersebut

# %%
kamus_normalisasi_kata = {}

#memasukkan kamus baku kedalam kamus_normalisasi_kata
for index, row in kamus_baku.iterrows():
    if row[0] not in kamus_normalisasi_kata:
        kamus_normalisasi_kata[row[0]] = row[1] 

def slang_convert_baku(document):
    return [kamus_normalisasi_kata[term] if term in kamus_normalisasi_kata else term for term in document]

# %%
df_new['Tokenisasi_Baku'] = df_new['tokenisasi'].apply(slang_convert_baku)

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
#
#                                            langkah01  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jum at jum at keempat di kal...
# 7  hikmah di balik musibah covid smg para pejabat...
# 8  cegah covid beserta jajaran polsek kuranji mel...
# 9  ya allah kami memohon pada mu perkenankanlah d...
#
#                                           tokenisasi  \
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jum, at, jum, at, keempa...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...
#
#                                      Tokenisasi_Baku
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jum, at, jum, at, keempa...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...

# %% [markdown]
# ### Menggabungkan Tokenisasi_baku menjadi satu kalimat lagi

# %%
#ini adalah list kosong untung menampung hasil dari tokenisasi baku yang terpisah menjadi satu
gabungan_tokenisasi_baku = []

#perulangan untuk menggabungkan tokenisasi_baku
for kata in df_new["Tokenisasi_Baku"].values:
    reviewkata = ""
    reviewkata = " ".join(kata)
    gabungan_tokenisasi_baku.append(reviewkata)

# %%
df_new["Tokenisasi_Baku"].values
# Out:
# array([list(['cegah', 'mata', 'rantai', 'covid', 'mari', 'kita', 'dirumah', 'saja', 'hingga', 'hari', 'minggu']),
#        list(['aku', 'mohon', 'yaallah', 'semoga', 'wabah', 'covid', 'menghilang', 'sebelum', 'ramadhan', 'datang']),
#        list(['pemprov', 'papua', 'naikkan', 'status', 'jadi', 'tanggap', 'darurat', 'covid', 'opm']),
#        list(['covid', 'belum', 'nyampe', 'prigen', 'mbak', 'hmm', 'hoax']),
#        list(['nyuruh', 'orang', 'pintar', 'lu', 'aja', 'togog', 'itu', 'kerumunan', 'orang', 'bisa', 'nularin', 'covid', 'lol', 'mikir']),
#        list(['pikir', 'balik', 'byk', 'mnde', 'plk', 'nk', 'setelkn', 'lepas', 'covid']),
#        list(['selamat', 'pagi', 'hari', 'jum', 'at', 'jum', 'at', 'keempat', 'di', 'kala', 'pandemi', 'covid', 'semoga', 'kita', 'semua', 'dikasih', 'kesehatan', 'aamiin']),
#        list(['hikmah', 'di', 'balik', 'musibah', 'covid', 'smg', 'para', 'pejabat', 'pemerintahan', 'sadar', 'lbh', 'mengedepankan', 'kekayaan', 'negara', 'utk', 'kesejahteraan', 'rakyat', 'indonesia', 'bukan', 'memperkaya', 'diri', 'sendiri', 'keluarga', 'dan', 'kepentingan', 'golongan', 'apalagi', 'membela', 'kepentingan', 'wna', 'yg', 'jelas', 'melukai', 'kepentingan', 'rakyat']),
#        list(['cegah', 'covid', 'beserta', 'jajaran', 'polsek', 'kuranji', 'melakukan', 'aksi', 'peduli', 'berupa', 'pembagian', 'masker', 'gratis', 'bagi', 'pengguna', 'jalan', 'kegiatan', 'ini', 'dilakukan', 'di', 'depan', 'polsek', 'kuranji', 'kamis', 'febriputraguci']),
#        list(['ya', 'allah', 'kami', 'memohon', 'pada', 'mu', 'perkenankanlah', 'doa', 'doa', 'kami', 'kerana', 'sesungguhnya', 'engkaulah', 'yang', 'maha', 'pengasih', 'lagi', 'maha', 'penyayang', 'ya', 'allah', 'lindungilah', 'kami', 'dari', 'penyakit', 'berjangkit', 'covid', 'aamiin', 'aamiin', 'ya', 'rabbal', 'lamin', 'stay', 'at', 'home', 'jangan', 'keluar', 'rumah']),
#        list(['sah', 'cegah', 'covid', 'meluas', 'pemerintah', 'revisi', 'hari', 'libur', 'dan', 'cuti', 'bersama']),
#        list(['bencana', 'nasional', 'covid', 'dprd', 'indramayu', 'minta', 'bumd', 'beri', 'keringanan', 'tagihan', 'kredit', 'hingga', 'tagihan', 'pdam']),
#        list(['cegah', 'covid', 'pemprov', 'dan', 'fkub', 'papua', 'barat', 'sepakat', 'adakan', 'doa', 'bersama', 'serentak', 'opm']),
#        list(['pagi', 'kenapa', 'ya', 'di', 'daerah', 'sy', 'cipinang', 'besar', 'selatan', 'rt', 'rw', 'nya', 'tdk', 'prnh', 'aware', 'dgn', 'warganya', 'setiap', 'ada', 'bantuan', 'tidak', 'pernah', 'transparansi', 'kejadian', 'covid', 'ini', 'jg', 'tidak', 'ada', 'tindakan', 'semprot', 'disinfektan', 'dbd', 'jg', 'banyak', 'tp', 'tidak', 'ada', 'fogging', 'tp', 'uang', 'kas', 'ttp', 'jalan']),
#        list(['skrinews', 'pdt', 'jimmy', 'mari', 'bersama', 'memerangi', 'virus', 'corona', 'covid', 'demi', 'menjaga', 'tanah', 'papua']),
#        list(['ada', 'cara', 'menyuruh', 'covid', 'segera', 'pergi', 'jaga', 'kebersihan', 'dan', 'ketertiban', 'bukankah', 'covid', 'telah', 'mendidik', 'kita', 'agar', 'selalu', 'menjaga', 'kebersihan', 'badan', 'pakaian', 'barang', 'dan', 'lingkungan', 'dengan', 'rajin', 'mandi', 'mencuci', 'tangan', 'dan', 'tidak', 'sembarangan', 'membuang', 'sampah']),
#        list(['kementerian', 'agama', 'provinsi', 'papua', 'barat', 'azis', 'hegemur', 'mengatakan', 'umat', 'islam', 'di', 'provinsi', 'papua', 'barat', 'diimbau', 'agar', 'tidak', 'menolak', 'pemakaman', 'jenazah', 'pasien', 'positif', 'terjangkit', 'covid', 'opm']),
#        list(['aku', 'baru', 'bangun', 'tidur', 'dan', 'menyeruput', 'kopi', 'sedikit', 'ketika', 'ibuk', 'mencak', 'gak', 'karuan', 'satu', 'orang', 'pahlawan', 'garis', 'depan', 'covid', 'meninggal', 'dunia', 'dan', 'ditolak', 'warga', 'setempat', 'mungkin', 'lebih', 'tepatnya', 'sekolompok', 'warga', 'yang', 'kurang', 'edukasi']),
#        list(['jangan', 'mudik', 'dong', 'ancaman', 'penyebaran', 'covid', 'yang', 'lebih', 'luas', 'tandatangani', 'petisi', 'via']),
#        list(['berita', 'seperti', 'ini', 'tidak', 'akan', 'ditengok', 'oleh', 'muflis', 'dungu', 'kecuali', 'berita', 'hoax', 'macam', 'kudeta', 'mbs', 'pangeran', 'kena', 'covid', 'yg', 'sumbernya', 'sama', 'dari', 'kaum', 'liberal']),
#        list(['giat', 'bhabinkamtibmas', 'polsek', 'tamalatea', 'bersama', 'aparatur', 'desa', 'kareloe', 'dan', 'relawan', 'melakukan', 'penyemprotan', 'disinfektan', 'untuk', 'mencegah', 'penyebaran', 'virus', 'covid']),
#        list(['temanggung', 'jawa', 'tengah', 'anggota', 'gugus', 'tugas', 'covid', 'kelurahan', 'mungseng', 'temanggung', 'mau', 'tak', 'bagiin', 'di', 'posko']),
#        list(['profil', 'operasional', 'bandara', 'ap', 'ii', 'di', 'tengah', 'pandemi', 'covid']),
#        list(['btw', 'long', 'weekend', 'ni', 'pada', 'mau', 'kemana', 'dulu', 'sebelum', 'ada', 'nya', 'si', 'covid', 'ini', 'long', 'weekend', 'itu', 'yang', 'paling', 'di', 'nanti', 'eh', 'skrng', 'mah', 'beneran', 'panjang', 'libur', 'nya', 'di', 'kasih', 'enak', 'dirumah', 'malah', 'ngedumel', 'bae', 'dasar', 'aku']),
#        list(['hallo', 'dan', 'mau', 'laporkan', 'adanya', 'kegiatan', 'yang', 'melanggar', 'ketentuan', 'tentang', 'jaga', 'jarak', 'selama', 'wabah', 'covid', 'kemana', 'ya']),
#        list(['hei', 'guys', 'gw', 'mau', 'ngajak', 'kalian', 'untuk', 'agar', 'pandemik', 'covid', 'ini', 'lekas', 'hilang', 'aamiin', 'gimana', 'kurangin', 'dah', 'tuh', 'nongki', 'halan', 'atau', 'segala', 'aktivitas', 'diluar', 'ruangan', 'yuk', 'belajar', 'utbk', 'aja', 'tau', 'sendirikan', 'pesaing', 'lo', 'tuh', 'buanyak', 'banget', 'yok']),
#        list(['jangan', 'ada', 'dusta', 'diantara', 'kita', 'kisah', 'pilu', 'dokter', 'menangani', 'pasien', 'yang', 'ternyata', 'positif', 'covid']),
#        list(['covid', 'telah', 'bermutasi', 'ada', 'gelombang', 'kedua', 'virus', 'corona']),
#        list(['salam', 'jumaat', 'ya', 'allah', 'kami', 'menadah', 'tangan', 'minta', 'keampunan', 'pada', 'mu', 'dan', 'berserah', 'diri', 'dengan', 'mu', 'dan', 'berilah', 'kekuatan', 'dan', 'kesihatan', 'yang', 'baik', 'jauhilah', 'kami', 'dari', 'segala', 'penyakit', 'berjangkit', 'covid', 'dan', 'hamba', 'mu', 'yang', 'sedang', 'berjuang', 'kesakitan', 'yang', 'berada', 'di', 'hospital']),
#        list(['saya', 'kuatir', 'test', 'covid', 'belum', 'menyeluruh', 'tau', 'nanti', 'ada', 'korban', 'tergeletak', 'mati', 'suspek', 'corona', 'ngeri']),
#        list(['ada', 'yang', 'kek', 'gue', 'saking', 'fokus', 'sama', 'berita', 'soal', 'covid', 'hari', 'ini', 'siap', 'siap', 'kerja', 'padahalan', 'tanggal', 'merah', 'yalord']),
#        list(['berarti', 'dah', 'lama', 'gak', 'gitaran', 'mungkin', 'mau', 'bikin', 'album', 'lagu', 'buat', 'corona', 'covid', 'yudhoyono']),
#        list(['berat', 'mbah', 'terlalu', 'banyak', 'kemungkinan', 'sedang', 'haid', 'gak', 'ndang', 'mampet', 'jualan', 'online', 'gak', 'payu', 'payu', 'lagi', 'horny', 'sing', 'lanang', 'mumet', 'covid', 'sudah', 'masak', 'enak', 'dapat', 'berkatan', 'yg', 'lebih', 'enak', 'sariawan', 'loro', 'untu', 'keputihan', 'murus', 'ilate', 'kecakot', 'bengese', 'anyar', 'masker', 'kerlisut', 'dst']),
#        list(['amalkan', 'langkah', 'langkah', 'pencegahan', 'penularan', 'covid', 'sebagai', 'amalan', 'dalam', 'kehidupan', 'seharian', 'kita']),
#        list(['kementerian', 'agama', 'provinsi', 'papua', 'barat', 'azis', 'hegemur', 'mengatakan', 'umat', 'islam', 'di', 'provinsi', 'papua', 'barat', 'diimbau', 'agar', 'tidak', 'menolak', 'pemakaman', 'jenazah', 'pasien', 'positifcterjangkit', 'covid', 'opm']),
#        list(['bumi', 'maafkan', 'kami', 'yang', 'tak', 'pernah', 'sadar', 'bahwa', 'kau', 'juga', 'butuh', 'istirahat']),
#        list(['kalau', 'ga', 'ada', 'covid', 'jam', 'segini', 'gue', 'udah', 'mulai', 'pendakian', 'dari', 'pos', 'cangkuang']),
#        list(['developers', 'biang', 'rusuh', 'proyek', 'konstruksi', 'swasta', 'termasuk', 'yg', 'dikecualikan', 'untuk', 'freeze', 'dlm', 'psbb', 'dki', 'oleh', 'gub', 'pdhl', 'dlm', 'permenkes', 'tdk', 'termasuk', 'yg', 'dikecualikan', 'juga', 'proyek', 'konstruksi', 'besar', 'berpotensi', 'menjadi', 'kluster', 'penyebaran', 'covid', 'krn', 'padat', 'bijimane', 'nih']),
#        list(['kalau', 'tidak', 'dimulai', 'dari', 'diri', 'sendiri', 'mana', 'mungkin', 'yukkk', 'kita', 'putus', 'mata', 'rantai', 'penyemangat', 'covid', 'di', 'indonesia', 'dimulai', 'dari', 'diri', 'sendiri']),
#        list(['sinergitas', 'tni', 'polri', 'untuk', 'mencegah', 'penyebaran', 'virus', 'covid']),
#        list(['kucing', 'bukan', 'penyebar', 'covid', 'kepada', 'manusia', 'jabatan', 'perkhidmatan', 'veterinar']),
#        list(['pemkab', 'wondama', 'perbanyak', 'pos', 'pemantauan', 'covid', 'opm']),
#        list(['covid', 'pelajar', 'unimas', 'berusia', 'tahun', 'maut']),
#        list(['murid', 'mamaku', 'dikasih', 'tugas', 'menggambar', 'poster', 'pencegahan', 'covid', 'anaknya', 'malah', 'pada', 'nggambar', 'virus', 'segede', 'gaban', 'dibawahnya', 'dikasih', 'tulisan', 'ya', 'allah', 'lindungilah', 'aku']),
#        list(['meluasnya', 'pandemi', 'coronavirus', 'disease', 'covid', 'di', 'indonesia', 'termasuk', 'di', 'papua', 'berdampak', 'pada', 'sejumlah', 'sektor', 'salah', 'satunya', 'perhotelan', 'opm']),
#        list(['ada', 'gelombang', 'kedua', 'virus', 'corona', 'covid', 'telah', 'bermutasi']),
#        list(['bantuan', 'masyarakat', 'terus', 'mengalir', 'rekening', 'gugus', 'tugas', 'covid', 'sudah', 'terisi', 'rp', 'miliar']),
#        list(['ada', 'cara', 'mnyuruh', 'covid', 'sgera', 'pergi', 'jangan', 'lagi', 'jauh', 'dari', 'allah', 'sang', 'maha', 'pencipta', 'bukankh', 'covid', 'telah', 'mendidik', 'kita', 'dlm', 'suasana', 'covid', 'aktif', 'menyebar', 'semua', 'org', 'ketakutan', 'semua', 'org', 'baru', 'mendekat', 'berdzikir', 'dan', 'berdoa', 'memohon', 'perlindungan', 'allah', 'sang', 'kholiq']),
#        list(['di', 'malaysia', 'kena', 'covid', 'temen', 'temen', 'lo', 'yang', 'pada', 'ga', 'punya', 'kerjaan', 'pada', 'pulang', 'ke', 'indonesia', 'ada', 'rb', 'orang', 'dan', 'juga', 'mereka', 'ber', 'resiko', 'bawa', 'tuh', 'virus', 'ga', 'boleh', 'pulang', 'juga']),
#        list(['skrinews', 'cegah', 'penyebaran', 'virus', 'corona', 'wa', 'awan', 'media', 'skri', 'jadi', 'satgas', 'relawan', 'covid', 'didesanya']),
#        list(['lebaran', 'sebentar', 'lagi', 'gara', 'covid', 'lebaran', 'apa', 'masih', 'pada', 'butuh', 'aksesoris', 'enggak', 'ya']),
#        list(['giat', 'bhabinkamtibmas', 'bersama', 'masyarakat', 'melakukan', 'penyemprotan', 'disinfektan', 'untuk', 'mencegah', 'penyebaran', 'virus', 'covid']),
#        list(['kasih', 'sayang', 'allah', 'di', 'balik', 'musibah', 'covid']),
#        list(['anggota', 'polsek', 'koba', 'himbau', 'para', 'pemuda', 'tidak', 'kumpul', 'kumpul', 'dan', 'segera', 'pulang', 'kerumahnya', 'masing', 'masing', 'untuk', 'mencegah', 'penyebaran', 'covid']),
#        list(['met', 'pagi', 'nkri', 'spy', 'trlalu', 'heboh', 'data', 'kematian', 'covid', 'jadikan', 'perbandingan', 'kematian', 'seluruh', 'prop', 'indon', 'sblm', 'wabah', 'corona', 'terjadi', 'indon', 'jk', 'jumlahnya', 'setara', 'kematian', 'sblm', 'stlh', 'corona', 'mk', 'jumlah', 'tsb', 'angka', 'kematian', 'norma', 'sj']),
#        list(['tido', 'la', 'tak', 'nak', 'harap', 'apa', 'apa', 'dia', 'dari', 'azali', 'takde', 'hati', 'macam', 'tu', 'cuba', 'berharap', 'covid', 'takde', 'je', 'tu', 'je']),
#        list(['untuk', 'mengetahui', 'bagaimana', 'mencegah', 'penyakit', 'wabak', 'covid', 'sila', 'baca', 'risalah', 'ini']),
#        list(['iya', 'sel', 'aku', 'liat', 'dengerin', 'lukman', 'sardi', 'bilang', 'rumah', 'sakit', 'penuh', 'makanya', 'disuruh', 'pulang', 'orang', 'awam', 'kan', 'taunya', 'diusir', 'padahal', 'triase', 'artinya', 'emang', 'di', 'jkt', 'parah', 'banget', 'covid', 'shg', 'orang', 'dg', 'sakit', 'parah', 'lain', 'mlh', 'jd', 'kena', 'triase']),
#        list(['kopi', 'pagi', 'ini', 'cukup', 'nikmat', 'kabar', 'baiknya', 'pemerintah', 'aceh', 'menyalurkan', 'bantuan', 'pokok', 'utk', 'masyarakat', 'terdampak', 'covid', 'dgn', 'kriteria', 'bukan', 'penerima', 'pkh', 'bpnt', 'alhamdulillah']),
#        list(['hingga', 'date', 'polri', 'tindak', 'kasus', 'penyimpangan', 'produksi', 'dan', 'distribusi', 'apd', 'covid']),
#        list(['eh', 'bacot', 'lu', 'lbih', 'parah', 'dari', 'covid', 'anjing', 'sia', 'ke', 'bele', 'pantat', 'korengan', 'sok', 'blgu']),
#        list(['lumpuhnya', 'peran', 'negara', 'dalam', 'menangani', 'covid', 'tegakkan', 'agar', 'terwujud']),
#        list(['my', 'liberty', 'ends', 'where', 'your', 'nose', 'begins', 'pas', 'banget', 'di', 'era', 'covid', 'dicolek', 'colek', 'hidungnya', 'di', 'masa', 'normal', 'aja', 'nggak', 'mau', 'apalagi', 'di', 'masa', 'covid']),
#        list(['terkejut', 'kami', 'terkanjat', 'je', 'warga', 'indonesia', 'terkejut', 'dgn', 'tindakan', 'pemerintah', 'malaysia', 'menjaga', 'rakyatnya', 'dgn', 'pemberian', 'pelbagai', 'insentif', 'dsaat', 'pelaksanaan', 'pkp', 'berikutan', 'penularan', 'wabak', 'covid', 'baca', 'komen', 'warga', 'indonesia', 'di', 'ruang', 'komen', 'youtube']),
#        list(['sugeng', 'ambal', 'warso', 'kita', 'bahgia', 'saat', 'ini', 'adalah', 'covid', 'segera', 'teratasi', 'dan', 'semua', 'bisa', 'melakukan', 'kegiatan', 'seperti', 'biasa']),
#        list(['tinggal', 'jawab', 'covid', 'emak', 'belum', 'lahir', 'dek', 'jadi', 'emak', 'gak', 'tau', 'emak', 'kan', 'waktu', 'itu', 'masih', 'jadi', 'hawa', 'nafsu']),
#        list(['bakal', 'susah', 'keknya', 'memutus', 'mata', 'rantai', 'covid', 'di', 'indonesia', 'selain', 'tentang', 'budaya', 'masyarakat', 'yang', 'mayoritas', 'belanja', 'ke', 'pasar', 'tradisional', 'masih', 'banyak', 'juga', 'yang', 'keluar', 'rumah', 'cuma', 'mau', 'ngereceh']),
#        list(['langkah', 'yg', 'dapat', 'di', 'ambil', 'pemerintah', 'dalam', 'mengatasi', 'dampak', 'covid', 'terhadap', 'kerjasama', 'internasional', 'jawab', 'pengumpulan', 'data', 'kesakitan', 'dan', 'kematian', 'penduduk', 'pemeriksaan', 'klinis', 'fisik', 'laboratorium', 'dan', 'penegakan', 'diagnosis']),
#        list(['kurangkan', 'risiko', 'awda', 'terhadap', 'jangkitan', 'virus', 'covid']),
#        list(['ini', 'tips', 'ilmuwan', 'cara', 'tingkatkan', 'kekebalan', 'tubuh', 'mari', 'bersama', 'kita', 'lawan', 'covid', 'sistem', 'ketahanan', 'tubuh', 'adalah', 'mekanisme', 'yang', 'efektif', 'untuk', 'menjaga', 'tubuh', 'dari', 'serangan', 'penyakit', 'via']),
#        list(['selamat', 'memperingati', 'jumat', 'agung', 'selamat', 'memaknai', 'arti', 'pengorbanan', 'nya', 'yang', 'sesungguhnya', 'demi', 'cinta', 'kasih', 'di', 'masa', 'kini', 'pengorbanan', 'kita', 'untuk', 'melawan', 'covid', 'juga', 'pasti', 'berbuah', 'baik', 'sama', 'seperti', 'datangnya', 'paskah', 'di', 'kemudian', 'hari', 'happy', 'good', 'friday']),
#        list(['pandemi', 'covid', 'mendikbud', 'dana', 'bos', 'bisa', 'digunakan', 'membeli', 'kuota', 'internet', 'siswa']),
#        list(['semoga', 'diberikan', 'kesehatan', 'jasmani', 'rohani', 'ya', 'dok', 'dan', 'semoga', 'kita', 'semua', 'selalu', 'dalam', 'lindungan', 'allah', 'swt', 'agar', 'terhindar', 'dari', 'fitnah', 'dajjal', 'aamiin', 'mulut', 'senantiasa', 'selalu', 'berdzikir', 'insyaallah', 'bs', 'mjdi', 'tameng', 'virus', 'covid', 'selain', 'ikhtiar']),
#        list(['lebih', 'narapidana', 'bebas', 'di', 'tengah', 'wabah', 'covid', 'termasuk', 'koruptor', 'serba', 'serbi', 'mmc']),
#        list(['semoga', 'segera', 'diberi', 'kesembuhan', 'jgn', 'coba', 'lg', 'menulis', 'corona', 'tentara', 'allah', 'virus', 'tdk', 'mengenal', 'sara', 'marilah', 'berdoa', 'spy', 'wabah', 'ini', 'segera', 'berakhir', 'amiiin']),
#        list(['kalo', 'emang', 'kehati', 'hatian', 'bisa', 'mencegah', 'corona', 'mungkin', 'pangeran', 'charles', 'tidak', 'akan', 'terpapar', 'covid', 'krn', 'hidupnya', 'paling', 'hati', 'dan', 'terjaga']),
#        list(['gejala', 'covid']),
#        list(['kemarin', 'yakin', 'sekali', 'kedepan', 'akan', 'seperti', 'ini', 'dan', 'itu', 'taunya', 'wabah', 'covid', 'merubah', 'semuannya', 'sekarang', 'doannya', 'samal', 'allah', 'mintannya', 'dirahmati', 'dan', 'dilindungi', 'dimudahkan', 'serta', 'menjadi', 'orang', 'yang', 'beruntung', 'jangan', 'sok', 'kuat', 'bro', 'kita', 'diatur', 'jangan', 'sok', 'mengatur']),
#        list(['covid']), list(['covid', 'oleh', 'renang', 'ra', 'to']),
#        list(['bapak', 'anies', 'dong', 'karena', 'beliau', 'dan', 'jajarannya', 'yang', 'dari', 'awal', 'konsisten', 'melawan', 'covid', 'hanya', 'saja', 'di', 'jegal', 'oleh', 'pusat']),
#        list(['disebabkan', 'pandemik', 'covid', 'penjarakan', 'sosial', 'perlu', 'menjadi', 'norma', 'baharu', 'sekurangnya', 'untuk', 'satu', 'tempoh', 'waktu', 'tertentu', 'untuk', 'tahun', 'ini', 'sekurangnya', 'perlu', 'ada', 'kawalan', 'pemantauan', 'atau', 'mungkin', 'batalkan', 'perhimpunan', 'sama', 'ada', 'perhimpunan', 'ramadan', 'aidilfitri', 'atau', 'haji']),
#        list(['san', 'bernardino', 'county', 'covid', 'data']),
#        list(['dpr', 'ri', 'bentuk', 'timwas', 'covid']),
#        list(['emang', 'serba', 'salah', 'mas', 'nggak', 'konpers', 'juga', 'nnti', 'dikira', 'nggak', 'ada', 'transparansi', 'dalam', 'menanggulangi', 'pandemi', 'covid', 'ini']),
#        list(['sehat', 'selalu', 'ya', 'ustadz', 'semoga', 'allah', 'swt', 'selalu', 'melindungi', 'anda', 'dan', 'keluarga', 'begitulah', 'faktanya', 'ustadz', 'dana', 'pendidikan', 'di', 'pakai', 'buat', 'penanganan', 'covid', 'jelas', 'dana', 'gak', 'ada', 'tp', 'sok', 'masih', 'mau', 'pindah', 'ibu', 'kota', 'mirissss']),
#        list(['baznas', 'buka', 'donasi', 'covid', 'lewat', 'smart', 'shadaqah', 'bni', 'syariah']),
#        list(['lagi', 'bayangin', 'ijazah', 'gw', 'bsk', 'ada', 'lambang', 'covid', 'nya']),
#        list(['mangtanku', 'besok', 'akad', 'ciyee', 'menikah', 'ditengah', 'pandemi', 'covid', 'ciyee']),
#        list(['ini', 'adalah', 'wujud', 'cinta', 'kasih', 'dan', 'duka', 'kami', 'warga', 'maluku', 'atas', 'meninggalnya', 'salah', 'satu', 'putra', 'terbaik', 'maluku', 'kaka', 'tercinta', 'kami', 'menyadari', 'bahwa', 'virus', 'covid', 'ada', 'dimanadan', 'mengancam', 'kami', 'tp', 'ketakutan', 'itu', 'terkalahkan', 'org', 'rasa', 'duka', 'kami', 'mohon', 'jgn', 'bully', 'kami']),
#        list(['jawaban', 'paling', 'wow', 'udah', 'bikin', 'apa', 'anda', 'buat', 'penanggulangan', 'covid', 'wisma', 'atlit', 'masih', 'butuh', 'relawan', 'ikut', 'yuuu', 'sayang']),
#        list(['demi', 'kesehatan', 'mental', 'lu', 'baca', 'berita', 'covid', 'sekali', 'sehari', 'aja', 'dan', 'apapun', 'yg', 'terjadi', 'setelah', 'lu', 'baca', 'gak', 'usah', 'hiraukan', 'skip', 'aja', 'udah', 'untk', 'hari', 'esok', 'atau', 'lusa', 'karna', 'itu', 'gak', 'baik', 'buat', 'lu']),
#        list(['covid', 'memiliki', 'arti', 'kata', 'co', 'yakni', 'corona', 'vi', 'yakni', 'virus', 'dan', 'yakni', 'disease', 'atau', 'penyakit', 'kemudian', 'ditambahkan', 'angka', 'yakni', 'mewakili', 'tahun', 'smg', 'puas', 'dgn', 'jwban', 'ini', 'halo', 'luna']),
#        list(['jalan', 'membantu', 'pihak', 'berkuasa', 'dalam', 'menanggani', 'penularan', 'wabak', 'covid', 'ft', 'sec', 'ft', 'sec']),
#        list(['ini', 'adalah', 'contoh', 'beberapa', 'kondisi', 'penerapan', 'alat', 'pengaman', 'di', 'apotek', 'agar', 'meminimalisir', 'penularan', 'covid', 'bagaimana', 'kondisi', 'di', 'apotek', 'anda', 'silahkan', 'share', 'dan', 'tag', 'medsos', 'kami', 'dengan', 'hashtag']),
#        list(['am', 'mrs', 'lestari', 'abyasa', 'dari', 'balikpapan', 'terima', 'kasih', 'kepada', 'rika', 'anderson', 'pinjaman', 'yang', 'memberikan', 'saya', 'pinjaman', 'tanpa', 'jaminan', 'juta', 'dalam', 'pandemi', 'covid', 'ini', 'anda', 'dapat', 'menghubungi', 'ibu', 'wa', 'phone', 'email', 'rikaandersonloancompany', 'saya']),
#        list(['menunggu', 'sampai', 'wabah', 'covid', 'mereda', 'sabar', 'ya', 'karena', 'keselamatan', 'orang', 'banyak', 'lebih', 'penting', 'dari', 'segalanya']),
#        list(['para', 'koruptor', 'kejahatan', 'lain', 'dibebaskan', 'alasan', 'krn', 'pandemi', 'covid']),
#        list(['jgn', 'lgi', 'ada', 'rasa', 'angkuh', 'sombong', 'rasa', 'besar', 'serba', 'bisa', 'bukankh', 'virus', 'corona', 'yg', 'kecil', 'tk', 'tmpak', 'mata', 'itu', 'tlah', 'mndidik', 'kita', 'bahwa', 'tdk', 'ada', 'yg', 'mampu', 'mncegahnya', 'jka', 'covid', 'ingin', 'dtang', 'mmpir', 'dan', 'covid', 'tdk', 'mngenal', 'status', 'sosial', 'miskin', 'atau', 'kaya', 'tua', 'atau', 'muda', 'pmbesar']),
#        list(['sudah', 'dinyatakan', 'covid', 'dari', 'klaster', 'umrah', 'di', 'sidrap']),
#        list(['ada', 'beberapa', 'gubernur', 'coba', 'diframing', 'dari', 'pusat', 'sbg', 'dlm', 'penangganan', 'covid', 'framing', 'ini', 'dilakukan', 'utk', 'menenggelankan', 'popularitas', 'gubernur', 'yg', 'dianggap', 'lawan', 'politik', 'padahal', 'sdh', 'mati', 'matian', 'berjuang', 'melawan', 'covid', 'di', 'daerahnya']),
#        list(['lagi', 'lagi', 'jenazah', 'covid', 'ditolak', 'dia', 'perawat', 'yang', 'meninggal', 'grgr', 'terpapar', 'covid']),
#        list(['pandemi', 'corona', 'mengancam', 'nasib', 'media', 'lokal']),
#        list(['covid', 'angka', 'kematian', 'hampiri', 'di', 'seluruh', 'dunia']),
#        list(['yg', 'ada', 'tuh', 'level', 'presiden', 'menyediakan', 'dana', 'spy', 'rakyat', 'yg', 'terkena', 'dampak', 'covid', 'tetap', 'bisa', 'di', 'rmh', 'tp', 'bisa', 'makan', 'layak', 'yg', 'dikoordinasi', 'dr', 'pusat', 'sampai', 'ke', 'pelosok', 'bekerja', 'melalui', 'jalurnya', 'bukan', 'bagi', 'di', 'jalan', 'ini', 'mah', 'kelas', 'cere']),
#        list(['penghulu', 'para', 'pengurus', 'masjid', 'sang', 'cipta', 'rasa', 'kota', 'cirebon', 'menggelar', 'ikhtiar', 'tolak', 'bala', 'dengan', 'bermunajat', 'bersama', 'dan', 'adzan', 'pitu', 'semoga', 'wabah', 'covid', 'segera', 'berakhir', 'aamiin', 'untuk', 'para', 'dokter', 'tim', 'medis', 'indonesia', 'tetap', 'semangat']),
#        list(['min', 'lpdp', 'ttp', 'ada', 'nggk', 'yaa', 'min', 'mengingat', 'dana', 'tetap', 'pendidikan', 'di', 'ahlikan', 'ke', 'penanggulangan', 'ekonomi', 'karena', 'covid']),
#        list(['leader', 'dlm', 'penyebaran', 'covid', 'kale', 'membuat', 'org', 'antri', 'akibat', 'efek', 'kejutnya']),
#        list(['wii', 'yg', 'berdampak', 'covid', 'itu', 'tdk', 'hanya', 'warga', 'miskin', 'berita', 'ini', 'judulnya', 'benar', 'isinya', 'yg', 'tdk', 'benar']),
#        list(['memanusiakan', 'manusia', 'adalah', 'salah', 'satu', 'bentuk', 'penghormatan', 'kita', 'pada', 'sesama', 'sedih', 'kalo', 'liat', 'jenazah', 'yg', 'meninggal', 'karena', 'covid', 'tidak', 'diterima', 'warga', 'setempat', 'untuk', 'dimakamkan']),
#        list(['ada', 'ancaman', 'penyebaran', 'covid', 'yang', 'lebih', 'luas', 'dr', 'dike', 'afifi', 'menbuat', 'petisi', 'kepada', 'presiden', 'untuk', 'keluarkan', 'kebijakan', 'menghentikan', 'semua', 'akses', 'transportasi', 'dari', 'dalam', 'dan', 'keluar', 'kota', 'tandatangani', 'petisi']),
#        list(['yaudah', 'di', 'gpp', 'let', 'covid', 'do', 'ur', 'duties', 'aja']),
#        list(['persib', 'potong', 'persen', 'gaji', 'pemain', 'karena', 'corona', 'covid']),
#        list(['virus', 'corona', 'covid', 'melanda', 'saat', 'indonesia', 'menghadapi', 'musim', 'pancaroba', 'ancaman', 'demam', 'berdarah', 'dengue', 'dbd', 'juga', 'sedang', 'menghantui']),
#        list(['allah', 'maha', 'kuasa', 'kisah', 'nyata', 'mengharukan', 'pelajar', 'muslimah', 'indonesia', 'yang', 'terkena', 'covid', 'di', 'new', 'york', 'alhamdulillah', 'allahu', 'akbar']),
#        list(['ngaur', 'kamu', 'mosok', 'tenaga', 'medis', 'meninggal', 'kamu', 'sangkutkan', 'dgn', 'fatwa', 'mui', 'emngya', 'semua', 'pasien', 'covid', 'itu', 'dari', 'mesjid', 'sumbernya', 'hadeuh']),
#        list(['sempat', 'nihil', 'tiga', 'hari', 'kini', 'pasien', 'positif', 'covid', 'bertambah', 'satu', 'orang']),
#        list(['lindungi', 'dokter', 'dari', 'paparan', 'covid', 'bppt', 'ri', 'luncurkan', 'aplikasi', 'mobile', 'covid', 'track']),
#        list(['semoga', 'insan', 'bocah', 'kontol', 'mampus', 'kena', 'covid', 'ya']),
#        list(['gejala', 'covid']),
#        list(['jumat', 'kesadaran', 'masyarakat', 'akan', 'pentingnya', 'berdiam', 'diri', 'dirumah', 'dalam', 'memutus', 'penyebaran', 'virus', 'covid', 'sangat', 'besar', 'dan', 'dari', 'kesadaran', 'diri', 'sendiri', 'terlihat', 'dr', 'pantauan', 'kijang', 'patroli', 'klungkung', 'disimpang', 'lepang', 'bypass', 'ib', 'mantra', 'klungkung', 'terpantau', 'tipis', 'lancar']),
#        list(['selamat', 'pagi', 'rute', 'tebet', 'depok', 'tersedia', 'pkl', 'time', 'wib', 'untuk', 'informasi', 'lengkap', 'jadwal', 'perjalanan', 'krl', 'mulai', 'date', 'bisa', 'di', 'lihat', 'pada', 'website', 'link', 'berikut', 'tks']),
#        list(['sangat', 'disayangkan', 'gorontalo', 'gagal', 'bertahan', 'sebagai', 'daerah', 'bebas', 'covid', 'hanya', 'karena', 'keegoisan', 'suatu', 'kaum', 'yang', 'enggan', 'tawakal', 'dan', 'memilih', 'untuk', 'takabur']),
#        list(['udah', 'pasti', 'sekrg', 'akan', 'berlindung', 'di', 'balik', 'wabah', 'gak', 'bisa', 'naikkan', 'gaji', 'krn', 'hrs', 're', 'alokasikan', 'dana', 'utk', 'respon', 'covid']),
#        list(['bayar', 'dlm', 'kereta', 'payah', 'ke', 'kaunter', 'musim', 'covid', 'ni', 'elakkn', 'guna', 'cash', 'guna', 'aplikasi', 'setel', 'dlm', 'kereta', 'sahaja', 'gunakn', 'setel', 'pam', 'minyak', 'setel', 'nikmati', 'rm', 'percuma', 'slps', 'pembelian', 'petrol', 'rm', 'pertama', 'anda', 'kod', 'rujukan', 'download', 'setel', 'sekarang']),
#        list(['musim', 'sakit', 'macam', 'ni', 'kan', 'agak', 'all', 'hantu', 'jin', 'momok', 'kena', 'tak', 'covid', 'ni', 'tak']),
#        list(['langkah', 'yg', 'dapat', 'di', 'ambil', 'pemerintah', 'dalam', 'mengatasi', 'dampak', 'covid', 'terhadap', 'perekonomian', 'indonesia', 'jawab', 'menjaga', 'konsumsi', 'rumah', 'tangga', 'miskin', 'melalui', 'berbagai', 'program', 'yang', 'dapat', 'dilakukan', 'segera', 'coverage', 'besar', 'dan', 'berdampak', 'langsung', 'ke', 'covid']),
#        list(['mendikbud', 'nadiem', 'makarim', 'mengambil', 'keputusan', 'terkait', 'pencairan', 'dana', 'kip', 'atau', 'kartu', 'indonesia', 'pintar', 'di', 'tengah', 'pandemi', 'virus', 'corona', 'covid']),
#        list(['kadar', 'kematian', 'covid', 'di', 'malaysia', 'masih', 'rendah']),
#        list(['pecah', 'telor', 'sarjana', 'covid']),
#        list(['baru', 'dapet', 'info', 'kalo', 'di', 'gang', 'sebelah', 'rumah', 'di', 'lumajang', 'udah', 'ada', 'yg', 'positif', 'covid', 'semoga', 'seluruh', 'keluarga', 'disana', 'aman']),
#        list(['darurat', 'militer', 'saja', 'pemerintah', 'bias', 'mewajibkan', 'rakyat', 'sebagai', 'serdadu', 'darurat', 'wabah', 'covid', 'dan', 'kesehatan', 'tentu', 'bisa', 'dilakukan', 'untuk', 'mewajibkan', 'para', 'konglomerat', 'untuk', 'keluarkan', 'hartanya', 'untuk', 'kepentingan', 'bersama']),
#        list(['tapi', 'anis', 'ni', 'tak', 'main', 'tiktok', 'dan', 'alhamdulillah', 'tak', 'kena', 'covid']),
#        list(['sbnarnya', 'sudah', 'tdk', 'kaget', 'klo', 'di', 'suruh', 'tinggal', 'rumah', 'sudah', 'terbiasa', 'dri', 'dulu', 'juga', 'social', 'distancing', 'krna', 'ada', 'yg', 'lebih', 'mematikan', 'dalam', 'masyarakat', 'lebih', 'dri', 'covid', 'yaitu', 'kebodohan']),
#        list(['badan', 'pom', 'luncurkan', 'informatorium', 'obat', 'covid', 'bersamaan', 'dengan', 'fgd', 'online', 'tentang', 'penanggulangan', 'covid', 'informatorium', 'ini', 'berisi', 'informasi', 'terkait', 'perkembangan', 'obat', 'covid', 'di', 'dunia', 'dan', 'tata']),
#        list(['revisi', 'kalau', 'tidak', 'ada', 'penambahan', 'jumlah', 'yang', 'positif', 'maka', 'untuk', 'pasien', 'covid', 'dengan', 'gejala', 'penyakit', 'yang', 'parah', 'atau', 'kritis', 'bisa', 'membutuhkan', 'waktu', 'pemulihan', 'klinis', 'sekitar', 'hingga', 'minggu']),
#        list(['syafakallah', 'semoga', 'allah', 'memberi', 'kesembuhan', 'pada', 'dr', 'tun', 'muzamal', 'widan', 'drp', 'wabak', 'covid', 'dan', 'sihat', 'seperti', 'biasa', 'aamiin', 'ya', 'rabbal', 'alamiin']),
#        list(['sambil', 'menunggu', 'orang', 'pintar', 'menemukan', 'obatnya', 'mari', 'waspada', 'tak', 'perlu', 'panik', 'berlebihan', 'faktanya', 'angka', 'kematian', 'bln', 'jauh', 'lebih', 'rendah', 'dr', 'tbc', 'covid', 'tidak', 'menyeramkan']),
#        list(['psbb', 'versus', 'covid']),
#        list(['dirumah', 'aja', 'jaga', 'kesehatan', 'dukung', 'pemerintah', 'memerangi', 'covid', 'dan', 'dirumah', 'ajapun', 'bisa', 'memperoleh', 'investasi', 'dengan', 'untung', 'banyakk', 'dengan', 'didukung', 'legalitas', 'aman', 'dan', 'konsep', 'hotel', 'dan', 'berkelas', 'perputasan']),
#        list(['meditation', 'to', 'fight', 'covid', 'meditasi', 'tidak', 'hanya', 'bermanfaat', 'bagi', 'pikiran', 'tetapi', 'juga', 'bagi', 'tubuh', 'dalam', 'satu', 'kesatuan', 'yang', 'harmonis', 'kehidupan', 'berlangsung', 'dalam', 'cinta', 'yang', 'mengubah', 'segala', 'sesuatu', 'menjadi']),
#        list(['pdhl', 'gak', 'mutlak', 'begitu', 'ya', 'beliau', 'lupa', 'ttg', 'adanya', 'cytokine', 'storm', 'pd', 'pasien', 'covid']),
#        list(['hrap', 'cukup', 'rt', 'nak', 'warna', 'hijau', 'nak', 'bawak', 'kerja', 'merempit', 'musim', 'covid']),
#        list(['salam', 'sapa', 'mana', 'boleh', 'salam', 'salam', 'pqah', 'musim', 'covid', 'ni', 'adoilah']),
#        list(['sebagai', 'bentuk', 'dukungan', 'terhadap', 'tim', 'medis', 'yang', 'tengah', 'berjuang', 'menghadapi', 'dan', 'merawat', 'pasien', 'covid', 'fpi', 'kembali', 'menyalurkan', 'sejumlah', 'bantuan', 'berupa', 'apd', 'serta', 'makanan', 'dan', 'minuman', 'bernutrisi', 'untuk', 'para', 'tim', 'medis']),
#        list(['semoga', 'wabah', 'covid', 'segera', 'berlalu', 'agar', 'lebaran', 'bisa', 'mudik', 'dan', 'berkumpul', 'dgn', 'keluarga']),
#        list(['buat', 'penelitian', 'covid']),
#        list(['tulisan', 'ini', 'saya', 'bikin', 'sekitar', 'minggu', 'lalu', 'br', 'dipublish', 'hari', 'lalu', 'saya', 'nulis', 'ttg', 'konser', 'virtual', 'yg', 'banyak', 'dilakukan', 'saat', 'pandemi', 'covid', 'tp', 'ini', 'jg', 'persiapan', 'utk', 'era', 'nantinya', 'serunya', 'semalam', 'liat', 'postingan', 'jrx', 'di', 'ig', 'menghubungkan', 'konspirasi', 'covid', 'ini', 'dan']),
#        list(['pkp', 'semua', 'orang', 'tak', 'nak', 'rugi', 'semua', 'nya', 'nak', 'bekerja', 'untuk', 'dapatkan', 'duit', 'tapi', 'kena', 'la', 'ingat', 'selagi', 'tak', 'selesai', 'kes', 'covid', 'belum', 'tentu', 'kita', 'semua', 'selamat', 'walaupun', 'kita', 'pergi', 'balik', 'kerja', 'lebih', 'baik', 'rugi', 'sementara', 'daripada', 'menyesal', 'selamanya']),
#        list(['allhumma', 'inn', 'dzu', 'bika', 'minal', 'barashi', 'wal', 'jun', 'bni', 'wal', 'judzmi', 'wa', 'sayy', 'bismillahirrahmanirrahim', 'semoga', 'wabah', 'covid', 'segera', 'berakhir', 'semoga', 'selalu', 'diberikan', 'kesehatan', 'keselamatan', 'serta', 'kebahagiaan', 'di', 'dunia', 'akhirat', 'aamiin']),
#        list(['ketua', 'wantim', 'mui', 'tolak', 'pengalihan', 'dana', 'haji', 'untuk', 'penanganan', 'covid']),
#        list(['ada', 'cara', 'menyuruh', 'covid', 'segera', 'pergi', 'jangan', 'lagi', 'pernah', 'abaikan', 'rumah', 'keluarga', 'dengan', 'terlalu', 'sibuk', 'di', 'luar', 'rumah', 'bukankan', 'covid', 'telah', 'mendidik', 'kita', 'untuk', 'banyak', 'tinggal', 'di', 'dalam', 'rumah', 'bersama', 'keluarga']),
#        list(['kasihan', 'ibu', 'korban', 'covid', 'yg', 'memohon', 'kepada', 'warga', 'video']),
#        list(['bukan', 'karena', 'covid', 'dia', 'hiv']),
#        list(['pandemi', 'covid', 'ketua', 'komisi', 'fatwa', 'mui', 'banten', 'himbau', 'masyarakat', 'tidak', 'ke', 'luar', 'daerah']),
#        list(['update', 'date', 'infografis', 'covid', 'positif', 'sembuh', 'meninggal']),
#        list(['pasien', 'pertama', 'covid', 'di', 'kabupaten', 'serang', 'terdeteksi', 'pulang', 'dari', 'jakarta']),
#        list(['time', 'musim', 'pkp', 'ni', 'pun', 'runner', 'boleh', 'jual', 'dadah', 'ek', 'yg', 'beli', 'dadah', 'pun', 'jenis', 'otak', 'kat', 'mana', 'tah', 'time', 'pkp', 'ni', 'kita', 'nak', 'doa', 'supaya', 'covid', 'ni', 'pulih', 'cepat', 'orang', 'hisap', 'dadah', 'minta', 'mati', 'cepat', 'eh', 'marah', 'plak', 'rasa']),
#        list(['cara', 'allah', 'membersihkan', 'bumi', 'ini', 'dari', 'polusi', 'kendaraan', 'ya', 'adanya', 'covid', 'ini']),
#        list(['teknis', 'rs', 'klaim', 'biaya', 'perawatan', 'pasien', 'covid']),
#        list(['dan', 'terjadi', 'lagi', 'penolakan', 'warga', 'terhadap', 'jenazah', 'perawat', 'yang', 'menangani', 'covid', 'di', 'rsup', 'kariadi', 'semarang', 'lokasi', 'suwakul', 'ungaran', 'video']),
#        list(['wagub', 'sumbar', 'minta', 'data', 'penerima', 'bantuan', 'korban', 'covid', 'tidak', 'duplikasi', 'dan', 'harus', 'detail']),
#        list(['selamat', 'pagi', 'kak', 'siti', 'mina', 'informasikan', 'plasa', 'telkom', 'depok', 'yakni', 'di', 'jl', 'arif', 'rahman', 'hakim', 'no', 'depok', 'saat', 'ini', 'tutup', 'sementara', 'hingga', 'batas', 'waktu', 'yang', 'belum', 'ditentukan', 'mengikuti', 'anjuran', 'dari', 'pemerintah', 'terkait', 'waspada', 'covid', 'dapat', 'diinformasikan', 'keperluannya', 'apa', 'kak']),
#        list(['doa', 'para', 'kiai', 'bawa', 'spirit', 'di', 'tengah', 'pandemi', 'covid', 'via']),
#        list(['pandemi', 'covid', 'kasus', 'dan', 'kematian']),
#        list(['pusing', 'julz', 'rumah', 'lagi', 'rame', 'covid', 'sini', 'rame', 'fwb', 'ga', 'ngotak']),
#        list(['semoga', 'wabah', 'covid', 'segera', 'berlalu', 'dan', 'indonesia', 'kembali', 'baik', 'baik', 'saja', 'amin', 'paling', 'serius']),
#        list(['ada', 'juga', 'lu', 'sbg', 'ketua', 'mutusin', 'utk', 'potong', 'gaji', 'seluruh', 'anggota', 'dpr', 'selama', 'beberapa', 'bulan', 'kedepan', 'utk', 'biaya', 'penanggulangan', 'wabah', 'covid', 'bukannya', 'galang', 'satgas', 'covid', 'utk', 'nyari', 'dana', 'mati', 'kekayaan', 'lo', 'gak', 'lo', 'bawa', 'ke', 'liang', 'lahat']),
#        list(['presiden', 'ri', 'sangat', 'cekatan', 'dalam', 'menghadapi', 'pandemi', 'covid', 'sangat', 'benar', 'sekalib', 'benar', 'sekalic', 'benard', 'benar', 'semuah']),
#        list(['biar', 'hukum', 'yg', 'brjalan', 'yuk', 'fokus', 'lawan', 'covid']),
#        list(['pasca', 'pandemi', 'covid', 'ada', 'orang', 'gila', 'nambah', 'nggak']),
#        list(['sbenarnya', 'ada', 'baiknya', 'covid', 'ni', 'berlaku', 'banyak']),
#        list(['meninggal', 'nya', 'relawan', 'covid', 'kalah', 'tenar', 'dengan', 'glen']),
#        list(['legislatif', 'sosialisasikan', 'bahaya', 'corona', 'hingga', 'ke', 'sawah', 'wakil', 'rakyat', 'di', 'dprd', 'kabupaten', 'kotabaru', 'kalimantan', 'selatan', 'gencar', 'melakukan', 'sosialisasi', 'kepada', 'masyarakat', 'dalam', 'mengantisipasi', 'bahaya', 'penyebaran', 'virus', 'covid', 'yang', 'dimulai', 'dari', 'wilayah', 'perkotaan']),
#        list(['rs', 'darurat', 'wisma', 'atlet', 'kemayoran', 'rawat', 'pasien', 'rumah', 'sakit', 'darurat', 'covid', 'wisma', 'atlet', 'di', 'kemayoran', 'jakarta', 'hingga', 'kamis', 'maret', 'merawat', 'pasien', 'rawat', 'inap', 'yang', 'terdiri', 'atas', 'pria', 'dan', 'perempuan', 'kasdam', 'jaya', 'brigjen', 'tni', 'saleh']),
#        list(['wabah', 'covid', 'merebak', 'perajin', 'masker', 'di', 'badung', 'panen', 'order']),
#        list(['dampak', 'covid', 'terhadap', 'kerjasama', 'internasional', 'jawab', 'adanya', 'kapasitas', 'perawatan', 'kesehatan', 'yang', 'cukup', 'harus', 'terintegrasi', 'antara', 'kebijakan', 'pada', 'bidang', 'kesehatan', 'dan', 'ekonomi', 'makro', 'kerja', 'sama', 'internasional', 'maupun', 'kemitraan', 'lintas', 'batas']),
#        list(['dpc', 'demokrat', 'maluku', 'tengah', 'bagikan', 'masker', 'di', 'pasar', 'binaya', 'kota', 'masohi', 'dan', 'di', 'depan', 'mini', 'market', 'hoky', 'namaelo', 'ini', 'lanjutan', 'dari', 'kegiatan', 'sebelumnya', 'agar', 'kader', 'turun', 'langsung', 'ke', 'masyarakat', 'ujar', 'ketua', 'dpc', 'samuel', 'thiemailattu']),
#        list(['kita', 'putus', 'dulu', 'ya', 'untuk', 'memutuskan', 'mata', 'rantai', 'covid', 'tak', 'cukup', 'dgn', 'jaga', 'jarak', 'saja', 'gunakan', 'masker', 'jika', 'keluar', 'rumah', 'lindungi', 'dirimu', 'karena', 'mungkin', 'saja', 'seseorang', 'disekitar', 'kita', 'terjangkit', 'covid']),
#        list(['dengan', 'diterapkannya', 'psbb', 'pembatasan', 'sosial', 'berskala', 'besar', 'dibebarapa', 'daerah', 'mari', 'refleksikan', 'pengorbanan', 'nya', 'dari', 'rumah', 'masing', 'masing', 'dan', 'kita', 'semua', 'berharap', 'mukjizat', 'segera', 'turun', 'menghalau', 'covid', 'have', 'blessing']),
#        list(['gila', 'serem', 'bgt', 'tante', 'gue', 'abis', 'ngeoprasi', 'org', 'sesaran', 'taunya', 'doi', 'positif', 'covid']),
#        list(['bersama', 'lawan', 'covid', 'polisi_palembang', 'anom_setyadji', 'andes', 'irwan_to', 'sik']),
#        list(['stay', 'safe', 'demi', 'mencergah', 'penyebaran', 'peluasan', 'wabah', 'covid', 'bareng', 'smartfren']),
#        list(['yuk', 'setelah', 'covid', 'berakhir', 'tapi', 'pengen', 'bgt', 'ke', 'argopuro', 'gas']),
#        list(['kenapa', 'harus', 'banget', 'ngikutin', 'berita', 'covid', 'karna', 'di', 'ruang', 'isolasi', 'itu', 'ga', 'enak', 'banget', 'astagfirullah', 'cukup', 'sekali', 'dan', 'semoga', 'virus', 'ini', 'segera', 'lenyap', 'dari', 'bumi']),
#        list(['punten', 'ini', 'rapid', 'test', 'covid', 'kah', 'mas', 'nya']),
#        list(['bali', 'terkini', 'date', 'efek', 'global', 'covid', 'simak', 'selengkapnya', 'pada', 'video', 'saya', 'link', 'youtube']),
#        list(['satu', 'hari', 'dia', 'covid', 'akan', 'pulang', 'ke', 'tempat', 'asalnya', 'tapi', 'smp', 'waktu', 'itu', 'kita', 'harus', 'terus', 'bersabar', 'dan', 'berdoa', 'moga', 'semuanya', 'dipermudahkan', 'ustaz', 'fawwaz']),
#        list(['mau', 'gimana', 'lagi', 'kalo', 'sampe', 'dia', 'bilang', 'masuk', 'tuh', 'covid', 'minta', 'bantuin', 'siapa', 'dia', 'kan', 'memusuhi', 'seluruh', 'dunia', 'bener', 'gak', 'si']),
#        list(['hahaha', 'org', 'yg', 'tak', 'waras', 'disaat', 'sperti', 'inicoba', 'jgn', 'gunakan', 'politik', 'jgn', 'grogoti', 'dulu', 'pemerintah', 'marilah', 'kita', 'sama', 'tumbangkan', 'covid', 'dulu', 'stelah', 'nanti', 'baru', 'kita', 'tumbangkan', 'presiden', 'bukan', 'begitu', 'kan', 'bang', 'memangbetul', 'ssh', 'org', 'yg', 'ambisi', 'kuasa', 'sabarlah']),
#        list(['kbri', 'phnom', 'penh', 'peduli', 'wni', 'dan', 'pencegahan', 'covid']),
#        list(['virus', 'covid', 'menyerang', 'paru', 'paru', 'tapi', 'virus', 'cinta', 'awak', 'menyerang', 'hati', 'saya', 'hehe']),
#        list(['hasil', 'rapid', 'test', 'covid', 'semua', 'ulama', 'di', 'tasimalaya', 'jabar', 'negatif', 'virus', 'corona', 'alhamdulillah', 'semoga', 'allah', 'senantiasa', 'selalu', 'menjaga', 'semua', 'ulama', 'kiyai', 'ustadz', 'ustadzah', 'da', 'pengurus', 'masjid', 'di', 'seluruh', 'indonesia', 'aamiin']),
#        list(['hms', 'itenas', 'bandung', 'melalui', 'satgas', 'covid', 'yayasan', 'wanadri', 'bekerjasama', 'dan', 'bersatu', 'melawan', 'covid', 'dengan', 'upaya', 'penggalangan', 'dana', 'yang', 'akan', 'digunakan', 'untuk', 'membeli', 'sejumlah', 'alat', 'perlengkapan', 'medis', 'di', 'sejumlah', 'rumah', 'sakit', 'di', 'jawa', 'barat']),
#        list(['hms', 'itenas', 'peduli', 'pandemi', 'covid', 'menghadirkan', 'berbagai', 'keprihatinan', 'sosial', 'di', 'seluruh', 'indonesia', 'sudah', 'saatnya', 'kita', 'keluarga', 'besar', 'hms', 'itenas', 'bandung', 'turun', 'tangan', 'memberikan', 'bantuan', 'kemanusiaan', 'ayo', 'berdonasi', 'untuk', 'dukung', 'perlengkapan', 'medis', 'tenaga', 'kesehatan', 'covid']),
#        list(['covid', 'mahasiswa', 'dan', 'pemda', 'andi', 'hasriadi', 'biarkan', 'kami', 'tetap', 'hidup', 'menjadi', 'generasi', 'pelanjut']),
#        list(['antisipasi', 'kemungkinan', 'lain', 'pasien', 'sesak', 'nafas', 'dikebumikan', 'dengan', 'protap', 'pemakaman', 'pdp', 'covid']),
#        list(['selagi', 'vaccine', 'tak', 'jumpa', 'selagi', 'tu', 'bahaya', 'covid', 'ni']),
#        list(['idup', 'udh', 'susah', 'bgt', 'ya', 'tambah', 'covid', 'makin', 'susah', 'perekonomian', 'beneran', 'anjlokk', 'udahann', 'kek', 'pandemi', 'ini']),
#        list(['cegah', 'penyebaran', 'virus', 'covid', 'puk', 'spai', 'fspmi', 'pt', 'nipro', 'indonesia', 'jaya', 'bagikan', 'masker', 'dan', 'hand', 'sanitizer', 'untuk', 'anggota']),
#        list(['kemenkeuri', 'tak', 'bisa', 'dipungkiri', 'aktivitas', 'perekonomian', 'yang', 'kian', 'tertekan', 'akibat', 'covid', 'membuat', 'banyak', 'orang', 'harus', 'kehilangan', 'pekerjaan', 'penghasilan', 'pemerintah', 'telah', 'menyusun', 'strategi', 'untuk']),
#        list(['koruptor', 'bebas', 'karena', 'alasan', 'covid', 'apakah', 'benar', 'ini', 'bukti', 'keberpihakan', 'pemerintah', 'kepada', 'tikus', 'tikus', 'negara', 'hmm', 'simak', 'jawabannya', 'di', 'video', 'ini']),
#        list(['ada', 'cra', 'mnyurh', 'covid', 'sgr', 'prg', 'jngn', 'lgi', 'mlas', 'ke', 'msjd', 'dll', 'bkankh', 'covid', 'tlh', 'mndidk', 'kta', 'bgaimna', 'sdh', 'strssnya', 'kta', 'tnpa', 'ada', 'tmpt', 'mmohn', 'brdoa', 'tk', 'bsa', 'bribdh', 'brjamah', 'shalt', 'di', 'msjd', 'dlm', 'suasna', 'btin', 'yg', 'dmai', 'bgaimna', 'sdhnya', 'mlps', 'sdr', 'kta', 'yg', 'mninggl', 'tnpa', 'dishltkn', 'di', 'msjd']),
#        list(['secara', 'langsung', 'mereka', 'sudah', 'odp', 'harus', 'lakukan', 'treat', 'pada', 'mreka', 'utk', 'dilakukan', 'screening', 'covid']),
#        list(['asrama', 'haji', 'pondok', 'gede', 'siap', 'digunakan', 'untuk', 'ruang', 'isolasi', 'covid']),
#        list(['ada', 'banyak', 'hikmah', 'dari', 'bencana', 'covid', 'salah', 'satunya', 'memperlihatkan', 'bahwa', 'disiplin', 'itu', 'bukan', 'kualitas', 'alamiah', 'manusia', 'tapi', 'memang', 'bentukan', 'dengan', 'paksaan']),
#        list(['kamis', 'malam', 'se', 'dunia', 'mengetuk', 'pintu', 'langit', 'dan', 'munajat', 'doa', 'memohon', 'pada', 'sang', 'khaliq', 'merayu', 'sang', 'maha', 'mendengar', 'meminta', 'sang', 'maha', 'adil', 'untuk', 'keselamatan', 'dunia', 'dari', 'wabah', 'covid', 'nu', 'ku', 'selalu', 'ada', 'tetap', 'ada', 'dan', 'terus', 'ada']),
#        list(['guna', 'memperkecil', 'ruang', 'penyebaran', 'covid', 'kami', 'menghimbau', 'untuk', 'saudaraku', 'dirantauan', 'agar', 'jangan', 'pulang', 'kampung', 'demi', 'keluarga', 'demi', 'indonesia']),
#        list(['hari', 'ini', 'hari', 'jumaat', 'anda', 'rindu', 'solat', 'jumaat', 'mudahan', 'covid', 'ini', 'berlalu', 'pergi', 'mudahan', 'peperangan', 'ini', 'kita', 'menang']),
#        list(['jom', 'amin', 'kan', 'ramai', 'ya', 'allah', 'semoga', 'covid', 'lenyap', 'sebelum', 'ramadhan', 'lindungilah', 'kami', 'semua', 'ya', 'allah', 'assalam']),
#        list(['kemarin', 'ortu', 'gue', 'minta', 'cekkin', 'tunjangan', 'sertifikasi', 'lucky', 'masih', 'lumayan', 'kalau', 'thr', 'batal', 'yaudah', 'asal', 'emang', 'digunakan', 'buat', 'covid', 'biar', 'kehidupan', 'cepat', 'normal', 'gedek', 'lama', 'lama', 'gini', 'terus']),
#        list(['covid', 'lari', 'kencang', 'memburu', 'mangsa', 'adminstrasi', 'psbb', 'jalan', 'di', 'tempat']),
#        list(['lagi', 'tim', 'gugus', 'tugas', 'covid', 'melakukan', 'penyemprotan', 'di', 'kawasan', 'medan', 'bagian', 'utara']),
#        list(['jujur', 'sih', 'udh', 'gapernah', 'ngikutin', 'berita', 'covid', 'bikin', 'pusingg']),
#        list(['heran', 'dengan', 'medsos', 'dan', 'media', 'mainstream', 'yg', 'di', 'angkat', 'kok', 'ojol', 'doang', 'tu', 'banyak', 'yg', 'lebih', 'sengsara', 'kayak', 'buruh', 'bangunan', 'buruh', 'serabutan', 'yg', 'tanpa', 'covid', 'aja', 'hidupnya', 'sudah', 'kacau']),
#        list(['asn', 'tni', 'polri', 'pegawai', 'bumn', 'dilarang', 'mudik', 'kudu', 'manut', 'ora', 'usah', 'ngeyel', 'ayo', 'bersatu', 'semoga', 'covid', 'segera', 'hilang', 'jaga', 'kebersihan', 'jaga', 'kesehatan']),
#        list(['kawasan', 'physical', 'distancing', 'dalam', 'upaya', 'pencegahan', 'covid']),
#        list(['mengalahkan', 'covid']),
#        list(['dua', 'warga', 'kabupaten', 'lampung', 'utara', 'yang', 'dinyatakan', 'positif', 'terpapar', 'covid', 'dikarantina', 'di', 'komplek', 'islamic', 'center', 'kotabumi', 'menurut', 'plt', 'bupati', 'budi', 'utomo', 'yang', 'juga', 'ketua', 'tim', 'gugus', 'tugas', 'penanggulangan', 'covid']),
#        list(['camana', 'nak', 'cari', 'rezeki', 'lebih', 'adakah', 'ada', 'pekerja', 'yg', 'kena', 'buang', 'kerja', 'dgan', 'ekonomi', 'kita', 'yg', 'terganggu', 'sekarang', 'ni', 'disebabkan', 'covid', 'bukannya', 'sekarang', 'masa', 'nak', 'bash', 'atau', 'kecam', 'sana', 'sini', 'pasal', 'isu', 'menteri', 'laa', 'artis', 'laa', 'kaum', 'itu', 'ini', 'buat', 'hal', 'laa']),
#        list(['presiden', 'tidak', 'ada', 'langkah', 'serius', 'hadapi', 'pandemi', 'covid', 'akan', 'menjadi', 'bom', 'waktu', 'bagi', 'semua', 'orang', 'indonesia', 'tidak', 'diyerima', 'di', 'dunia', 'internasional']),
#        list(['yang', 'nolak', 'jenazah', 'covid', 'apalagi', 'kalo', 'itu', 'nakes', 'pada', 'ga', 'takut', 'apa', 'ya', 'jenazah', 'mereka', 'ditolak', 'bumi', 'gapernah', 'nonton', 'sinetron', 'hidayah', 'apa', 'gimana']),
#        list(['posko', 'siaga', 'covid', 'data', 'para', 'pemudik']),
#        list(['planning', 'buat', 'liburan', 'ke', 'sabang', 'batall', 'howalaahh', 'covid', 'covid']),
#        list(['bagi', 'anda', 'korban', 'phk', 'atau', 'dirumahkan', 'akibat', 'penyebaran', 'virus', 'covid', 'yuk', 'daftarkan', 'diri', 'anda', 'untuk', 'mendapatkan', 'kartu', 'pra', 'kerja', 'mudah', 'koq']),
#        list(['bersama', 'bersatu', 'lawan', 'penyebaran', 'virus', 'corona', 'covid', 'jaga', 'kesehatan', 'jauhi', 'kerumunan', 'cuci', 'tangan', 'pakai', 'sabun', 'serta', 'tetap', 'infolingga']),
#        list(['bencana', 'nasional', 'covid', 'satu', 'warga', 'positif', 'corona', 'pemprov', 'ntt', 'koordinasi', 'dengan', 'kemenkes']),
#        list(['hingga', 'saat', 'ini', 'korut', 'mengklaim', 'masih', 'terbebas', 'dari', 'virus', 'covid', 'padahal', 'dua', 'negara', 'yang', 'mengapitnya', 'yakni', 'kosel', 'dan', 'china', 'menjadi', 'episentrum']),
#        list(['kapolrestabes', 'semarang', 'bersama', 'forkopimda', 'kota', 'semarang', 'memberikan', 'himbauan', 'kepada', 'masyarakat', 'untuk', 'memakai', 'masker', 'jaga', 'kebersihan', 'dan', 'tetap', 'di', 'rumah', 'guna', 'memutus', 'mata', 'rantai', 'penyebaran', 'virus', 'corona', 'atau', 'covid']),
#        list(['kalo', 'ga', 'covid', 'hari', 'ini', 'tuh', 'udah', 'nangis', 'di', 'pojokan']),
#        list(['ketularan', 'covid', 'dari', 'pemudik', 'jakarta', 'kota', 'kediri', 'tambah', 'kasus', 'positif']),
#        list(['siapapun', 'yang', 'berpolitik', 'di', 'tengah', 'wabah', 'covid', 'itu', 'tidak', 'peduli', 'rakyat']),
#        list(['bersama', 'bersatu', 'melawan', 'penyebaran', 'virus', 'corona', 'covid', 'di', 'kabupaten', 'lingga', 'jaga', 'kesehatan', 'jauhi', 'kerumunan', 'cuci', 'tangan', 'pakai', 'sabun', 'serta', 'tetap', 'infolingga', 'info']),
#        list(['banyak', 'tanggal', 'merah', 'pas', 'lagi', 'wabah', 'covid']),
#        list(['pejuang', 'covid']),
#        list(['gpp', 'nyai', 'mendingan', 'gitu', 'hibur', 'diri', 'daripada', 'keluar', 'rumah', 'tetap', 'sehat', 'nyai', 'semoga', 'alloh', 'melindungi', 'dan', 'menjauhkan', 'wabah', 'covid', 'utk', 'kita', 'semua', 'aamiin', 'yra']),
#        list(['lebih', 'narapidana', 'bebas', 'di', 'tengah', 'wabah', 'covid', 'termasuk', 'koruptor', 'kebayang', 'ga', 'sih', 'klo', 'kita', 'sudah', 'susah', 'payah', 'menangkap', 'tikus', 'sampai', 'dapat', 'banyak', 'bgt', 'itupun', 'blm', 'semuanya', 'eeehh', 'tau', 'mau', 'dilepaskan', 'kyk', 'apa', 'jadinya', 'rumah', 'kita']),
#        list(['physical', 'distancing', 'memutus', 'rantai', 'penyebaran', 'covid']),
#        list(['seram', 'jatuh', 'tempo', 'massal', 'covid', 'di', 'usa', 'bagaimana', 'dengan', 'indonesia']),
#        list(['repotnya', 'sissy', 'priscillia', 'dampingi', 'anak', 'sekolah', 'sambil', 'bekerja', 'dari', 'rumah', 'selama', 'wabah', 'covid']),
#        list(['tak', 'kenal', 'lelah', 'tim', 'gugus', 'tugas', 'covid', 'kembali', 'semprot', 'pemukiman', 'padat', 'penduduk', 'di', 'belawan']),
#        list(['begitu', 'ntar', 'bnyak', 'yg', 'kena', 'covid', 'si', 'miskin', 'yg', 'dituduh', 'bawa', 'virus', 'ya', 'nasib', 'jadi', 'org', 'miskin', 'ky', 'gw', 'kuli', 'proyek', 'sopir', 'ambulans', 'dan', 'kang', 'gali', 'kubur', 'bakal', 'kena', 'getahnya', 'lindungi', 'kami', 'kaum', 'miskin', 'ya', 'rabb']),
# ...
#        list(['antisipasi', 'penyebaran', 'covid', 'ini', 'arahan', 'gubernur', 'jatim']),
#        list(['rm', 'talian', 'sokongan', 'emosi', 'dan', 'psikososial', 'covid', 'beroperasi', 'setiap', 'hari', 'pagi', 'petang', 'hubungi', 'atau']),
#        list(['tgk', 'betapa', 'mudahnya', 'droplet', 'covid', 'untuk', 'merebak', 'dalam', 'kawasan', 'tertutup', 'peraturan', 'mudah', 'musim', 'covid', 'kalau', 'sakit', 'batuk', 'jangan', 'mengada', 'nak', 'keluar', 'tempat', 'org', 'ramai', 'elakkan', 'dari', 'menyentuh', 'muka', 'semasa', 'berada', 'di', 'luar', 'pakai', 'mask', 'semasa', 'diluar', 'dan', 'cuci', 'tangan']),
#        list(['achmad', 'yurianto', 'tetap', 'menjaga', 'jarak', 'pada', 'saat', 'kontak', 'sosial', 'hindari', 'kerumunan', 'hindari', 'pertemuan', 'pertemuan', 'yang', 'menghadirkan', 'banyak', 'orang', 'ini', 'penting', 'untuk', 'mencegah', 'penularan', 'covid']),
#        list(['sepertinya', 'anak', 'krakatau', 'mengalami', 'gejala', 'covid']),
#        list(['kaya', 'covid', 'aja', 'yg', 'lagi', 'terkenal']),
#        list(['cegah', 'covid', 'dengan', 'tetap', 'di', 'rumah', 'ajah']),
#        list(['mantaaap', 'polda', 'jateng', 'proses', 'tiga', 'pelaku', 'penolak', 'pemakaman', 'jenazah', 'covid', 'sudah', 'kami', 'amankan', 'tiga', 'orang', 'yang', 'diduga', 'memprovokasi', 'warga', 'untuk', 'menolak', 'pemakaman', 'jenazah', 'tersebut']),
#        list(['apa', 'hubungan', 'covid', 'dgn', 'pandemi', 'lainnya', 'apa', 'yang', 'dapat', 'disimpulkan', 'dari', 'peristiwa', 'pandemi', 'yg', 'pernah', 'terjadi', 'di', 'dunia', 'termasuk', 'covid', 'apa', 'hikmah', 'covid', 'yg', 'bisa', 'diambil', 'utk', 'masa', 'mendatang']),
#        list(['sumbang', 'barangan', 'keperluan', 'serta', 'risalah', 'covid']),
#        list(['sehat', 'sehat', 'mas', 'semoga', 'covid', 'ini', 'lekas', 'usai', 'agar', 'ekonomi', 'pulih', 'kembali']),
#        list(['tu', 'kadang', 'suka', 'ketawa', 'ngeliat', 'org', 'indo', 'yg', 'ngetwit', 'dgn', 'nada', 'seolah', 'sg', 'salah', 'kelabakan', 'menangani', 'covid', 'smntr', 'dianya', 'gatau', 'keseharian', 'di', 'sg', 'stay', 'jg', 'di', 'indo', 'yg', 'juga', 'nggak', 'lebih', 'baik', 'dlm', 'penanganan', 'covid', 'tp', 'yaudahlah', 'ya', 'biarin', 'aja', 'kalo', 'bs', 'bikin', 'dia', 'feel', 'better', 'kasian']),
#        list(['di', 'tengah', 'masa', 'darurat', 'covid', 'kua', 'tamalate', 'makassar', 'tetap', 'memberikan', 'layanan', 'menikahkan', 'pasangan', 'suami', 'istri', 'di', 'kantornya']),
#        list(['kerjasama', 'pengadaan', 'obat', 'covid', 'indonesia', 'dengan', 'jepang', 'dan', 'india', 'pusat', 'siaran', 'pers', 'indonesia']),
#        list(['covid', 'anggota', 'kkm', 'positif', 'setakat', 'date']),
#        list(['operasi', 'nyahkuman', 'di', 'sekitar', 'pekan', 'simunjan', 'cegah', 'penularan', 'covid', 'dapatkan', 'berita', 'penuh', 'di', 'fb']),
#        list(['penumpang', 'gelap', 'bernama', 'covid']),
#        list(['patroli', 'dialogis', 'personil', 'polsek', 'palu', 'utara', 'melaksanaka', 'giat', 'patroli', 'himbauan', 'dan', 'bagi', 'selebaran', 'maklumat', 'kapolri', 'tentang', 'bahaya', 'dan', 'cara', 'menangkal', 'penyebaran', 'wabah', 'virus', 'corona', 'atau', 'covid', 'di', 'swalayan', 'pasar', 'dan', 'spbu', 'kegiatan', 'ini', 'rutin', 'dilakukan', 'oleh', 'polsek', 'palu', 'utara']),
#        list(['update', 'tanggal', 'date', 'indonesia', 'mengumumkan', 'orang', 'kasus', 'baru', 'covid', 'total', 'orang', 'dalam', 'perawatan', 'orang', 'sembuh', 'orang', 'meninggal', 'dunia', 'orang']),
#        list(['jokowi', 'pembatasan', 'sosial', 'dan', 'protokol', 'kesehatan', 'yang', 'ketat', 'sudah', 'kita', 'terapkan', 'untuk', 'mengendalikan', 'penyebaran', 'covid', 'sementara', 'untuk', 'mengurangi', 'dampak', 'perekonomian', 'yang', 'mengikutinya', 'pemerintah', 'mengeluarkan', 'paket', 'insentif', 'ekonomi', 'untuk', 'warga']),
#        list(['ada', 'posko', 'covid', 'berdiri', 'di', 'sidoarjo', 'dilengkapi', 'fasilitas', 'alat', 'kesehatan', 'dan', 'apd']),
#        list(['ketika', 'dapet', 'obat', 'methylprednisolone', 'dan', 'cefi', 'ingin', 'rasanya', 'tidak', 'minum', 'itu', 'tapi', 'dokter', 'langsung', 'bilang', 'minumnya', 'de', 'biar', 'cespleng', 'wayahna', 'bisi', 'disangka', 'covid', 'mun', 'gohgoy', 'wae', 'jangan', 'lupa', 'minum', 'air', 'anget', 'kalo', 'bisa', 'akhirnya', 'minum', 'obat', 'dewa', 'dan', 'bom', 'itu']),
#        list(['sobat', 'kukm', 'tahukah', 'anda', 'bahwa', 'rapat', 'anggota', 'koperasi', 'dapat', 'dilaksanakan', 'melalui', 'media', 'online', 'maupun', 'secara', 'tertulis', 'di', 'saat', 'maraknya', 'penyebaran', 'virus', 'covid', 'ini', 'koperasi', 'tetap', 'dapat', 'melaksanakan', 'rat', 'dengan', 'secara']),
#        list(['egois', 'bgm', 'kondisi', 'terkini', 'negara', 'adidaya', 'as', 'stlh', 'diserang', 'virus', 'corona', 'rupanya', 'pmerintah', 'as', 'smkin', 'mmprlihatkan', 'wjh', 'asli', 'sikap', 'egois', 'bgitu', 'nyta', 'ditunjukkan', 'bhkn', 'kpd', 'negara', 'tetangga', 'yg', 'tlh', 'brjasa', 'mnyelamatkannya', 'dr', 'msa', 'sulit', 'akibat', 'pandemi', 'covid']),
#        list(['punya', 'teman', 'yang', 'usahanya', 'terdampak', 'covid', 'dan', 'psbb', 'mungkin', 'ini', 'bisa', 'membantu']),
#        list(['gara', 'gara', 'tiap', 'hari', 'baca', 'berita', 'ttg', 'covid', 'pas', 'mau', 'search', 'lagu', 'kesukaan', 'di', 'google', 'yg', 'terketik', 'secara', 'refleks', 'malah', 'covid', 'mau', 'nge', 'wa', 'temen', 'yg', 'ke', 'ketik', 'malah', 'covid', 'bukannya', 'nama', 'temen', 'gua', 'mau', 'revisi', 'judul', 'artikel', 'lagi', 'refleks', 'ngetik', 'covid', 'covid', 'haunts', 'me']),
#        list(['tolong', 'kuarantin', 'kluster', 'kayangan', 'disini', 'biar', 'malam', 'mimpi', 'kena', 'kusta', 'covid']),
#        list(['yess', 'aku', 'bahkan', 'kmren', 'priksanya', 'ke', 'rs', 'yg', 'nampung', 'pasien', 'covid', 'tp', 'ttep', 'hati', 'sih', 'jaga', 'jarak', 'cuci', 'tangan', 'dst']),
#        list(['komsos', 'babinsa', 'gubeng', 'edukasi', 'warga', 'cegah', 'penyebaran', 'covid']),
#        list(['ketua', 'bawaslu', 'kabupaten', 'magetan', 'hendrad', 'subiyakto', 'mengatakan', 'pihaknya', 'mengadakan', 'bhakti', 'sosial', 'ini', 'dalam', 'rangka', 'ulang', 'tahun', 'bawaslu', 'yang', 'ke', 'dan', 'membangun', 'solidaritas', 'kebangsaan', 'melawan', 'covid', 'atau', 'virus', 'corona']),
#        list(['antisipasi', 'penularan', 'covid', 'polres', 'tanjung', 'balai', 'himbau', 'masyarakat', 'yang', 'masih', 'berkerumun', 'agar', 'kembali', 'kerumah']),
#        list(['ringkasnya', 'positive', 'thinking', 'yang', 'keliru', 'menghadapi', 'covid', 'songolas', 'akibatnya', 'ilusi', 'kontrol', 'ilusi', 'superioritas', 'ilusi', 'kemungkinan']),
#        list(['pasien', 'covid', 'jambi', 'diisolasi', 'apakah', 'keluarga', 'gubernur', 'fu']),
#        list(['grafik', 'perkembangan', 'kasus', 'covid', 'di', 'kabupaten', 'bantul', 'date']),
#        list(['mari', 'bersama', 'kita', 'putus', 'rantai', 'penyebaran', 'virus', 'covid', 'stay', 'home', 'tetap', 'tenang', 'tetap', 'waspada', 'sayangi', 'diri', 'anda', 'dan', 'keluarga', 'anda']),
#        list(['dicurhatin', 'si', 'pasien', 'covid', 'yg', 'lagi', 'jenuh', 'bete', 'karna', 'harus', 'di', 'ruang', 'isolasi', 'mulu', 'idupnya', 'rebahan', 'main', 'hape', 'makan', 'mandi', 'repeat']),
#        list(['anggota', 'komisi', 'ii', 'minta', 'kepala', 'daerah', 'ambil', 'langkah', 'strategis', 'tangani', 'corona', 'covid', 'news']),
#        list(['angka', 'positif', 'covid', 'tembus', 'pemerintah', 'masyarakat', 'belum', 'disiplin']),
#        list(['tapi', 'kalau', 'tersangkut', 'covid', 'mcm', 'mana', 'aku', 'lagi', 'sarankan', 'keluar', 'pakai', 'mask', 'supaya', 'kau', 'tak', 'menyebar', 'dan', 'di', 'sebarkan']),
#        list(['covid', 'ikut', 'memukul', 'perekonomian', 'dan', 'pemerintah', 'pun', 'memberikan', 'stimulus', 'bagi', 'dunia', 'usaha', 'dan', 'industri', 'berapa', 'jumlah', 'umkm', 'di', 'indonesia']),
#        list(['distensif', 'distensif', 'ke', 'kali', 'ini', 'kita', 'akan', 'berdiskusi', 'terkait', 'penangan', 'covid', 'dalam', 'pandangan', 'kesehatan', 'masyarakat', 'dengan', 'narasumber', 'dr', 'irvan', 'afriandi', 'dr', 'grad', 'dipl', 'oeh', 'mph', 'selaku', 'wakil', 'dekan', 'fakultas', 'kedokteran', 'unpad']),
#        list(['apalagi', 'orang', 'yg', 'lebih', 'berbahaya', 'dari', 'covid', 'lurus', 'belok', 'pergi']),
#        list(['salah', 'satu', 'temen', 'ngegame', 'ada', 'yang', 'positif', 'covid', 'aku', 'yakin', 'dia', 'bakal', 'sembuh', 'dan', 'baik', 'baik', 'saja', 'tapi', 'ngerti', 'dia', 'panik', 'dan', 'ketakutan', 'aku', 'langsung', 'sedih']),
#        list(['masa', 'covid', 'ni', 'la', 'kita', 'nak', 'hiburkan', 'orang', 'dengan', 'kebodohan']),
#        list(['pak', 'gubernur', 'trend', 'positif', 'covid', 'di', 'sulsel', 'semakin', 'hari', 'semakin', 'mengkhawatirkan', 'apa', 'lg', 'di', 'daerah', 'bnyk', 'pemudik', 'dr', 'jkt', 'dan', 'mksr', 'kami', 'daerah', 'cemas', 'sekali', 'pak', 'apa', 'lg', 'ada', 'otg', 'pak', 'sebaiknya', 'psbb', 'maki', 'juga', 'kodong', 'cepat', 'ki', 'sblum', 'terlambat', 'kasian']),
#        list(['nkri', 'lawan', 'corona', 'hasil', 'tes', 'swab', 'empat', 'wanita', 'praja', 'ipdn', 'negatif', 'covid']),
#        list(['surat', 'terbuka', 'dokter', 'pdui', 'hrs', 'jd', 'perhatian', 'who', 'kemarin', 'livestreaming', 'katakan', 'jutaan', 'item', 'alat', 'apd', 'telah', 'dikirim', 'ke', 'negara', 'bin', 'malah', 'buka', 'lowongan', 'kerja', 'bagi', 'yg', 'mau', 'jd', 'relawan', 'covid', 'aneh', 'bingung', 'hadapi', 'wabah', 'covid', 'berutang', 'cepat', 'gak', 'bingung', 'iya', 'gak', 'sih']),
#        list(['nanya', 'dong', 'pertama', 'kali', 'covid', 'ada', 'di', 'indonesia', 'kpn', 'ya', 'maret', 'tgl', 'brp', 'gtu']),
#        list(['jika', 'kawalan', 'ketat', 'melalui', 'kebenaran', 'yg', 'diberikan', 'kerajaan', 'kepada', 'sebahagian', 'industri', 'berjaya', 'dilaksanakan', 'tanpa', 'mencetuskan', 'kenaikan', 'mendadak', 'kes', 'positif', 'covid', 'kita', 'mampu', 'menyelamatkan', 'nyawa', 'kedudukan', 'sosio', 'ekonomi', 'rakyat', 'dan', 'kewangan', 'negara']),
#        list(['kami', 'informasikan', 'sebaran', 'kasus', 'covid', 'di', 'kabupaten', 'bantul', 'berdasarkan', 'data', 'dari', 'dinas', 'kesehatan', 'kabupaten', 'bantul', 'per', 'sabtu', 'pukul', 'wib', 'terdapat', 'pasien', 'positif', 'dari', 'kecamatan', 'bambanglipuro', 'yang', 'sembuh']),
#        list(['setelah', 'covid', 'selesai', 'pasti', 'semua', 'akan', 'memudar', 'sedih', 'tapi', 'ya', 'mau', 'bagaimana', 'lagi', 'heuheu']),
#        list(['kalau', 'gak', 'ada', 'covid', 'entah', 'berapa', 'puluh', 'tahun', 'yang', 'akan', 'datang', 'ya', 'dok']),
#        list(['gak', 'heran', 'sih', 'udah', 'bertahun', 'tahun', 'aja', 'masih', 'banyak', 'yg', 'blm', 'paham', 'penularan', 'hiv', 'aids', 'ngejauhin', 'penderitanya', 'karna', 'takut', 'tertular', 'apalagi', 'covid', 'yg', 'baru', 'beberapa', 'bulan', 'ini', 'bukti', 'masyarakat', 'masih', 'sulit', 'dpt', 'informasi', 'yg', 'benar', 'atau', 'emang', 'mereka', 'emang', 'susah', 'dikasih', 'taunya']),
#        list(['saat', 'indonesia', 'berjibaku', 'melawan', 'pandemi', 'covid', 'sungguh', 'sia', 'sia', 'bila', 'seorang', 'yang', 'terbukti', 'ahli', 'dan', 'kaya', 'pengalaman', 'justru', 'berada', 'di', 'penjara']),
#        list(['tapi', 'sejak', 'covid', 'udah', 'hilang', 'di', 'peredaran', 'padahal', 'buat', 'berkebun', 'juga', 'enak', 'terus', 'ga', 'bau', 'meskipun', 'keringetan', 'kayak', 'sarung', 'tangan', 'yg', 'di', 'ace', 'yg', 'harga', 'an', 'tapi', 'emang', 'agak', 'pendek', 'yg', 'ikea']),
#        list(['terima', 'kasih', 'kepada', 'para', 'dokter', 'perawat', 'serta', 'tenaga', 'medis', 'lainnya', 'yang', 'turut', 'membantu', 'dalam', 'memberantas', 'pandemi', 'covid', 'untuk', 'membantu', 'para', 'tenaga', 'medis', 'kalian', 'tetep', 'ya', 'jangan', 'lupa', 'untuk', 'stock', 'yupi', 'kesukaan', 'kalian', 'biar', 'hepi', 'teruss', 'meskipun', 'di', 'rumah', 'ajaaa']),
#        list(['ketua', 'pengarah', 'kesihatan', 'datuk', 'dr', 'noor', 'hisham', 'abdullah', 'berkata', 'pihaknya', 'membuat', 'saringan', 'ke', 'atas', 'penduduk', 'di', 'menara', 'plaza', 'city', 'one', 'dan', 'daripada', 'jumlah', 'itu', 'positif', 'covid']),
#        list(['bagi', 'aku', 'elok', 'je', 'rmo', 'ni', 'fasa', 'ke', 'ni', 'patut', 'diperketatkan', 'lagi', 'tak', 'boleh', 'lah', 'sesetangah', 'industri', 'di', 'buka', 'barber', 'shop', 'lah', 'apa', 'lah', 'tahu', 'semua', 'rugi', 'tapi', 'demi', 'kesihatan', 'demi', 'negara', 'bebas', 'covid', 'kena', 'berkorban']),
#        list(['amerika', 'egois', 'potret', 'buruknya', 'negara', 'kapitalis', 'tangangi', 'covid']),
#        list(['imbas', 'pandemi', 'covid', 'renault', 'liburkan', 'karyawan', 'tim', 'hingga', 'akhir', 'mei']),
#        list(['malam', 'ini', 'nu', 'dan', 'muhammadiyah', 'inggris', 'kaji', 'voluntarisme', 'covid']),
#        list(['corona', 'makin', 'merajalela', 'motivator', 'tung', 'desem', 'waringin', 'positif', 'terinfeksi', 'covid', 'lewat']),
#        list(['benar', 'la', 'yb', 'elok', 'tak', 'kena', 'darah', 'tinggi', 'dari', 'kena', 'covid']),
#        list(['covid', 'aja', 'yg', 'ilang', 'kamu', 'jangan']),
#        list(['covid', 'menyusahkan', 'semuanya']),
#        list(['penerima', 'harus', 'beragama', 'islam', 'lembaga', 'bantuan', 'berbasis', 'agama', 'memangnya', 'tidak', 'mau', 'atau', 'tidak', 'boleh', 'membantu', 'orang', 'susah', 'yang', 'beragama', 'lain', 'sih', 'syarat', 'penerima', 'bantuan', 'covid', 'di', 'bangka', 'belitung', 'harus', 'beragama', 'islam']),
#        list(['ayo', 'kita', 'bersama', 'sama', 'cegah', 'penyebaran', 'covid']),
#        list(['lg', 'covid', 'gini', 'hidup', 'semua', 'susah', 'mau', 'mkn', 'susah', 'cari', 'nafkah', 'juga', 'susah', 'pgn', 'nangis', 'teriak', 'tp', 'ya', 'prcuma', 'mesti', 'sabar', 'dan', 'kuat', 'ada', 'tuhan', 'bersamaku']),
#        list(['yarabbi', 'banyak', 'banget', 'ya', 'berita', 'perawat', 'atau', 'pasien', 'yg', 'postif', 'covid', 'ditolak', 'jenazahnya', 'waktu', 'mau', 'dimakamkan', 'gila', 'jahat', 'bgt', 'ya', 'manusia']),
#        list(['kita', 'sebagai', 'rakyat', 'yang', 'prihatin', 'dan', 'mahukan', 'yang', 'terbaik', 'untuk', 'negara', 'akan', 'ikut', 'pkp', 'utk', 'banteras', 'wabak', 'covid']),
#        list(['apa', 'ini', 'bisa', 'diartikan', 'untuk', 'sembuh', 'dari', 'infeksi', 'covid', 'kita', 'bisa', 'makan', 'tanah', 'dok']),
#        list(['pobia', 'covid', 'mengalahkan', 'pobia', 'mantan', 'para', 'manteman', 'yg', 'gagal', 'move', 'on']),
#        list(['kalo', 'kata', 'temen', 'gue', 'masa', 'covid', 'gini', 'semua', 'anak', 'indigo', 'jadi', 'indihome']),
#        list(['anggota', 'komisi', 'ii', 'minta', 'kepala', 'daerah', 'ambil', 'langkah', 'strategis', 'tangani', 'corona', 'covid']),
#        list(['lama', 'sangat', 'cuti', 'covid', 'ni', 'baik', 'raya', 'terus']),
#        list(['seluruh', 'negara', 'di', 'dunia', 'mengalami', 'masa', 'sulit', 'karena', 'covid', 'rakyat', 'indonesia', 'bersatu', 'bahu', 'membahu', 'mendukung', 'dan', 'mendoakan', 'pemerintah', 'agar', 'nusantara', 'dapat', 'melewati', 'masa', 'sulit', 'ini', 'bukankah', 'agama', 'itu', 'untuk', 'membawa', 'kita', 'kepada', 'kebaikan', 'sadarlah', 'kawan']),
#        list(['setelah', 'covid', 'dan', 'skripsi', 'disaster', 'selesai', 'mau', 'bgt', 'bljr', 'masak', 'lagi', 'terutama', 'bikin', 'kueh']),
#        list(['malam', 'ini', 'projek', 'benda', 'boleh', 'bincang', 'malam', 'di', 'fb', 'persatuan', 'belia', 'harmoni', 'malaysia', 'covid', 'impak', 'terhadap', 'negara', 'ekonomi', 'dan', 'mahasiswa', 'jangan', 'lepaskan', 'peluang', 'ni', 'akhlak', 'khidmat', 'ukhuwah']),
#        list(['pontang', 'panting', 'di', 'koyak', 'covid']),
#        list(['masalahnya', 'sekarang', 'isu', 'jangkitan', 'covid', 'alaaaa', 'bosan', 'laaa', 'jangan', 'laaa', 'sebab', 'barber', 'geng', 'nak', 'buat', 'duit', 'nak', 'menyusahkan', 'dah', 'dah', 'laa', 'tu', 'cukup', 'laaa', 'nama', 'seorang', 'doctor', 'tapi', 'tak', 'leh', 'pikiaq'])],
#       dtype=object)

# %%
df_new["Hasil Ahkir"] = gabungan_tokenisasi_baku

# %%
gabungan_tokenisasi_baku
# Out:
# ['cegah mata rantai covid mari kita dirumah saja hingga hari minggu',
#  'aku mohon yaallah semoga wabah covid menghilang sebelum ramadhan datang',
#  'pemprov papua naikkan status jadi tanggap darurat covid opm',
#  'covid belum nyampe prigen mbak hmm hoax',
#  'nyuruh orang pintar lu aja togog itu kerumunan orang bisa nularin covid lol mikir',
#  'pikir balik byk mnde plk nk setelkn lepas covid',
#  'selamat pagi hari jum at jum at keempat di kala pandemi covid semoga kita semua dikasih kesehatan aamiin',
#  'hikmah di balik musibah covid smg para pejabat pemerintahan sadar lbh mengedepankan kekayaan negara utk kesejahteraan rakyat indonesia bukan memperkaya diri sendiri keluarga dan kepentingan golongan apalagi membela kepentingan wna yg jelas melukai kepentingan rakyat',
#  'cegah covid beserta jajaran polsek kuranji melakukan aksi peduli berupa pembagian masker gratis bagi pengguna jalan kegiatan ini dilakukan di depan polsek kuranji kamis febriputraguci',
#  'ya allah kami memohon pada mu perkenankanlah doa doa kami kerana sesungguhnya engkaulah yang maha pengasih lagi maha penyayang ya allah lindungilah kami dari penyakit berjangkit covid aamiin aamiin ya rabbal lamin stay at home jangan keluar rumah',
#  'sah cegah covid meluas pemerintah revisi hari libur dan cuti bersama',
#  'bencana nasional covid dprd indramayu minta bumd beri keringanan tagihan kredit hingga tagihan pdam',
#  'cegah covid pemprov dan fkub papua barat sepakat adakan doa bersama serentak opm',
#  'pagi kenapa ya di daerah sy cipinang besar selatan rt rw nya tdk prnh aware dgn warganya setiap ada bantuan tidak pernah transparansi kejadian covid ini jg tidak ada tindakan semprot disinfektan dbd jg banyak tp tidak ada fogging tp uang kas ttp jalan',
#  'skrinews pdt jimmy mari bersama memerangi virus corona covid demi menjaga tanah papua',
#  'ada cara menyuruh covid segera pergi jaga kebersihan dan ketertiban bukankah covid telah mendidik kita agar selalu menjaga kebersihan badan pakaian barang dan lingkungan dengan rajin mandi mencuci tangan dan tidak sembarangan membuang sampah',
#  'kementerian agama provinsi papua barat azis hegemur mengatakan umat islam di provinsi papua barat diimbau agar tidak menolak pemakaman jenazah pasien positif terjangkit covid opm',
#  'aku baru bangun tidur dan menyeruput kopi sedikit ketika ibuk mencak gak karuan satu orang pahlawan garis depan covid meninggal dunia dan ditolak warga setempat mungkin lebih tepatnya sekolompok warga yang kurang edukasi',
#  'jangan mudik dong ancaman penyebaran covid yang lebih luas tandatangani petisi via',
#  'berita seperti ini tidak akan ditengok oleh muflis dungu kecuali berita hoax macam kudeta mbs pangeran kena covid yg sumbernya sama dari kaum liberal',
#  'giat bhabinkamtibmas polsek tamalatea bersama aparatur desa kareloe dan relawan melakukan penyemprotan disinfektan untuk mencegah penyebaran virus covid',
#  'temanggung jawa tengah anggota gugus tugas covid kelurahan mungseng temanggung mau tak bagiin di posko',
#  'profil operasional bandara ap ii di tengah pandemi covid',
#  'btw long weekend ni pada mau kemana dulu sebelum ada nya si covid ini long weekend itu yang paling di nanti eh skrng mah beneran panjang libur nya di kasih enak dirumah malah ngedumel bae dasar aku',
#  'hallo dan mau laporkan adanya kegiatan yang melanggar ketentuan tentang jaga jarak selama wabah covid kemana ya',
#  'hei guys gw mau ngajak kalian untuk agar pandemik covid ini lekas hilang aamiin gimana kurangin dah tuh nongki halan atau segala aktivitas diluar ruangan yuk belajar utbk aja tau sendirikan pesaing lo tuh buanyak banget yok',
#  'jangan ada dusta diantara kita kisah pilu dokter menangani pasien yang ternyata positif covid',
#  'covid telah bermutasi ada gelombang kedua virus corona',
#  'salam jumaat ya allah kami menadah tangan minta keampunan pada mu dan berserah diri dengan mu dan berilah kekuatan dan kesihatan yang baik jauhilah kami dari segala penyakit berjangkit covid dan hamba mu yang sedang berjuang kesakitan yang berada di hospital',
#  'saya kuatir test covid belum menyeluruh tau nanti ada korban tergeletak mati suspek corona ngeri',
#  'ada yang kek gue saking fokus sama berita soal covid hari ini siap siap kerja padahalan tanggal merah yalord',
#  'berarti dah lama gak gitaran mungkin mau bikin album lagu buat corona covid yudhoyono',
#  'berat mbah terlalu banyak kemungkinan sedang haid gak ndang mampet jualan online gak payu payu lagi horny sing lanang mumet covid sudah masak enak dapat berkatan yg lebih enak sariawan loro untu keputihan murus ilate kecakot bengese anyar masker kerlisut dst',
#  'amalkan langkah langkah pencegahan penularan covid sebagai amalan dalam kehidupan seharian kita',
#  'kementerian agama provinsi papua barat azis hegemur mengatakan umat islam di provinsi papua barat diimbau agar tidak menolak pemakaman jenazah pasien positifcterjangkit covid opm',
#  'bumi maafkan kami yang tak pernah sadar bahwa kau juga butuh istirahat',
#  'kalau ga ada covid jam segini gue udah mulai pendakian dari pos cangkuang',
#  'developers biang rusuh proyek konstruksi swasta termasuk yg dikecualikan untuk freeze dlm psbb dki oleh gub pdhl dlm permenkes tdk termasuk yg dikecualikan juga proyek konstruksi besar berpotensi menjadi kluster penyebaran covid krn padat bijimane nih',
#  'kalau tidak dimulai dari diri sendiri mana mungkin yukkk kita putus mata rantai penyemangat covid di indonesia dimulai dari diri sendiri',
#  'sinergitas tni polri untuk mencegah penyebaran virus covid',
#  'kucing bukan penyebar covid kepada manusia jabatan perkhidmatan veterinar',
#  'pemkab wondama perbanyak pos pemantauan covid opm',
#  'covid pelajar unimas berusia tahun maut',
#  'murid mamaku dikasih tugas menggambar poster pencegahan covid anaknya malah pada nggambar virus segede gaban dibawahnya dikasih tulisan ya allah lindungilah aku',
#  'meluasnya pandemi coronavirus disease covid di indonesia termasuk di papua berdampak pada sejumlah sektor salah satunya perhotelan opm',
#  'ada gelombang kedua virus corona covid telah bermutasi',
#  'bantuan masyarakat terus mengalir rekening gugus tugas covid sudah terisi rp miliar',
#  'ada cara mnyuruh covid sgera pergi jangan lagi jauh dari allah sang maha pencipta bukankh covid telah mendidik kita dlm suasana covid aktif menyebar semua org ketakutan semua org baru mendekat berdzikir dan berdoa memohon perlindungan allah sang kholiq',
#  'di malaysia kena covid temen temen lo yang pada ga punya kerjaan pada pulang ke indonesia ada rb orang dan juga mereka ber resiko bawa tuh virus ga boleh pulang juga',
#  'skrinews cegah penyebaran virus corona wa awan media skri jadi satgas relawan covid didesanya',
#  'lebaran sebentar lagi gara covid lebaran apa masih pada butuh aksesoris enggak ya',
#  'giat bhabinkamtibmas bersama masyarakat melakukan penyemprotan disinfektan untuk mencegah penyebaran virus covid',
#  'kasih sayang allah di balik musibah covid',
#  'anggota polsek koba himbau para pemuda tidak kumpul kumpul dan segera pulang kerumahnya masing masing untuk mencegah penyebaran covid',
#  'met pagi nkri spy trlalu heboh data kematian covid jadikan perbandingan kematian seluruh prop indon sblm wabah corona terjadi indon jk jumlahnya setara kematian sblm stlh corona mk jumlah tsb angka kematian norma sj',
#  'tido la tak nak harap apa apa dia dari azali takde hati macam tu cuba berharap covid takde je tu je',
#  'untuk mengetahui bagaimana mencegah penyakit wabak covid sila baca risalah ini',
#  'iya sel aku liat dengerin lukman sardi bilang rumah sakit penuh makanya disuruh pulang orang awam kan taunya diusir padahal triase artinya emang di jkt parah banget covid shg orang dg sakit parah lain mlh jd kena triase',
#  'kopi pagi ini cukup nikmat kabar baiknya pemerintah aceh menyalurkan bantuan pokok utk masyarakat terdampak covid dgn kriteria bukan penerima pkh bpnt alhamdulillah',
#  'hingga date polri tindak kasus penyimpangan produksi dan distribusi apd covid',
#  'eh bacot lu lbih parah dari covid anjing sia ke bele pantat korengan sok blgu',
#  'lumpuhnya peran negara dalam menangani covid tegakkan agar terwujud',
#  'my liberty ends where your nose begins pas banget di era covid dicolek colek hidungnya di masa normal aja nggak mau apalagi di masa covid',
#  'terkejut kami terkanjat je warga indonesia terkejut dgn tindakan pemerintah malaysia menjaga rakyatnya dgn pemberian pelbagai insentif dsaat pelaksanaan pkp berikutan penularan wabak covid baca komen warga indonesia di ruang komen youtube',
#  'sugeng ambal warso kita bahgia saat ini adalah covid segera teratasi dan semua bisa melakukan kegiatan seperti biasa',
#  'tinggal jawab covid emak belum lahir dek jadi emak gak tau emak kan waktu itu masih jadi hawa nafsu',
#  'bakal susah keknya memutus mata rantai covid di indonesia selain tentang budaya masyarakat yang mayoritas belanja ke pasar tradisional masih banyak juga yang keluar rumah cuma mau ngereceh',
#  'langkah yg dapat di ambil pemerintah dalam mengatasi dampak covid terhadap kerjasama internasional jawab pengumpulan data kesakitan dan kematian penduduk pemeriksaan klinis fisik laboratorium dan penegakan diagnosis',
#  'kurangkan risiko awda terhadap jangkitan virus covid',
#  'ini tips ilmuwan cara tingkatkan kekebalan tubuh mari bersama kita lawan covid sistem ketahanan tubuh adalah mekanisme yang efektif untuk menjaga tubuh dari serangan penyakit via',
#  'selamat memperingati jumat agung selamat memaknai arti pengorbanan nya yang sesungguhnya demi cinta kasih di masa kini pengorbanan kita untuk melawan covid juga pasti berbuah baik sama seperti datangnya paskah di kemudian hari happy good friday',
#  'pandemi covid mendikbud dana bos bisa digunakan membeli kuota internet siswa',
#  'semoga diberikan kesehatan jasmani rohani ya dok dan semoga kita semua selalu dalam lindungan allah swt agar terhindar dari fitnah dajjal aamiin mulut senantiasa selalu berdzikir insyaallah bs mjdi tameng virus covid selain ikhtiar',
#  'lebih narapidana bebas di tengah wabah covid termasuk koruptor serba serbi mmc',
#  'semoga segera diberi kesembuhan jgn coba lg menulis corona tentara allah virus tdk mengenal sara marilah berdoa spy wabah ini segera berakhir amiiin',
#  'kalo emang kehati hatian bisa mencegah corona mungkin pangeran charles tidak akan terpapar covid krn hidupnya paling hati dan terjaga',
#  'gejala covid',
#  'kemarin yakin sekali kedepan akan seperti ini dan itu taunya wabah covid merubah semuannya sekarang doannya samal allah mintannya dirahmati dan dilindungi dimudahkan serta menjadi orang yang beruntung jangan sok kuat bro kita diatur jangan sok mengatur',
#  'covid',
#  'covid oleh renang ra to',
#  'bapak anies dong karena beliau dan jajarannya yang dari awal konsisten melawan covid hanya saja di jegal oleh pusat',
#  'disebabkan pandemik covid penjarakan sosial perlu menjadi norma baharu sekurangnya untuk satu tempoh waktu tertentu untuk tahun ini sekurangnya perlu ada kawalan pemantauan atau mungkin batalkan perhimpunan sama ada perhimpunan ramadan aidilfitri atau haji',
#  'san bernardino county covid data',
#  'dpr ri bentuk timwas covid',
#  'emang serba salah mas nggak konpers juga nnti dikira nggak ada transparansi dalam menanggulangi pandemi covid ini',
#  'sehat selalu ya ustadz semoga allah swt selalu melindungi anda dan keluarga begitulah faktanya ustadz dana pendidikan di pakai buat penanganan covid jelas dana gak ada tp sok masih mau pindah ibu kota mirissss',
#  'baznas buka donasi covid lewat smart shadaqah bni syariah',
#  'lagi bayangin ijazah gw bsk ada lambang covid nya',
#  'mangtanku besok akad ciyee menikah ditengah pandemi covid ciyee',
#  'ini adalah wujud cinta kasih dan duka kami warga maluku atas meninggalnya salah satu putra terbaik maluku kaka tercinta kami menyadari bahwa virus covid ada dimanadan mengancam kami tp ketakutan itu terkalahkan org rasa duka kami mohon jgn bully kami',
#  'jawaban paling wow udah bikin apa anda buat penanggulangan covid wisma atlit masih butuh relawan ikut yuuu sayang',
#  'demi kesehatan mental lu baca berita covid sekali sehari aja dan apapun yg terjadi setelah lu baca gak usah hiraukan skip aja udah untk hari esok atau lusa karna itu gak baik buat lu',
#  'covid memiliki arti kata co yakni corona vi yakni virus dan yakni disease atau penyakit kemudian ditambahkan angka yakni mewakili tahun smg puas dgn jwban ini halo luna',
#  'jalan membantu pihak berkuasa dalam menanggani penularan wabak covid ft sec ft sec',
#  'ini adalah contoh beberapa kondisi penerapan alat pengaman di apotek agar meminimalisir penularan covid bagaimana kondisi di apotek anda silahkan share dan tag medsos kami dengan hashtag',
#  'am mrs lestari abyasa dari balikpapan terima kasih kepada rika anderson pinjaman yang memberikan saya pinjaman tanpa jaminan juta dalam pandemi covid ini anda dapat menghubungi ibu wa phone email rikaandersonloancompany saya',
#  'menunggu sampai wabah covid mereda sabar ya karena keselamatan orang banyak lebih penting dari segalanya',
#  'para koruptor kejahatan lain dibebaskan alasan krn pandemi covid',
#  'jgn lgi ada rasa angkuh sombong rasa besar serba bisa bukankh virus corona yg kecil tk tmpak mata itu tlah mndidik kita bahwa tdk ada yg mampu mncegahnya jka covid ingin dtang mmpir dan covid tdk mngenal status sosial miskin atau kaya tua atau muda pmbesar',
#  'sudah dinyatakan covid dari klaster umrah di sidrap',
#  'ada beberapa gubernur coba diframing dari pusat sbg dlm penangganan covid framing ini dilakukan utk menenggelankan popularitas gubernur yg dianggap lawan politik padahal sdh mati matian berjuang melawan covid di daerahnya',
#  'lagi lagi jenazah covid ditolak dia perawat yang meninggal grgr terpapar covid',
#  'pandemi corona mengancam nasib media lokal',
#  'covid angka kematian hampiri di seluruh dunia',
#  'yg ada tuh level presiden menyediakan dana spy rakyat yg terkena dampak covid tetap bisa di rmh tp bisa makan layak yg dikoordinasi dr pusat sampai ke pelosok bekerja melalui jalurnya bukan bagi di jalan ini mah kelas cere',
#  'penghulu para pengurus masjid sang cipta rasa kota cirebon menggelar ikhtiar tolak bala dengan bermunajat bersama dan adzan pitu semoga wabah covid segera berakhir aamiin untuk para dokter tim medis indonesia tetap semangat',
#  'min lpdp ttp ada nggk yaa min mengingat dana tetap pendidikan di ahlikan ke penanggulangan ekonomi karena covid',
#  'leader dlm penyebaran covid kale membuat org antri akibat efek kejutnya',
#  'wii yg berdampak covid itu tdk hanya warga miskin berita ini judulnya benar isinya yg tdk benar',
#  'memanusiakan manusia adalah salah satu bentuk penghormatan kita pada sesama sedih kalo liat jenazah yg meninggal karena covid tidak diterima warga setempat untuk dimakamkan',
#  'ada ancaman penyebaran covid yang lebih luas dr dike afifi menbuat petisi kepada presiden untuk keluarkan kebijakan menghentikan semua akses transportasi dari dalam dan keluar kota tandatangani petisi',
#  'yaudah di gpp let covid do ur duties aja',
#  'persib potong persen gaji pemain karena corona covid',
#  'virus corona covid melanda saat indonesia menghadapi musim pancaroba ancaman demam berdarah dengue dbd juga sedang menghantui',
#  'allah maha kuasa kisah nyata mengharukan pelajar muslimah indonesia yang terkena covid di new york alhamdulillah allahu akbar',
#  'ngaur kamu mosok tenaga medis meninggal kamu sangkutkan dgn fatwa mui emngya semua pasien covid itu dari mesjid sumbernya hadeuh',
#  'sempat nihil tiga hari kini pasien positif covid bertambah satu orang',
#  'lindungi dokter dari paparan covid bppt ri luncurkan aplikasi mobile covid track',
#  'semoga insan bocah kontol mampus kena covid ya',
#  'gejala covid',
#  'jumat kesadaran masyarakat akan pentingnya berdiam diri dirumah dalam memutus penyebaran virus covid sangat besar dan dari kesadaran diri sendiri terlihat dr pantauan kijang patroli klungkung disimpang lepang bypass ib mantra klungkung terpantau tipis lancar',
#  'selamat pagi rute tebet depok tersedia pkl time wib untuk informasi lengkap jadwal perjalanan krl mulai date bisa di lihat pada website link berikut tks',
#  'sangat disayangkan gorontalo gagal bertahan sebagai daerah bebas covid hanya karena keegoisan suatu kaum yang enggan tawakal dan memilih untuk takabur',
#  'udah pasti sekrg akan berlindung di balik wabah gak bisa naikkan gaji krn hrs re alokasikan dana utk respon covid',
#  'bayar dlm kereta payah ke kaunter musim covid ni elakkn guna cash guna aplikasi setel dlm kereta sahaja gunakn setel pam minyak setel nikmati rm percuma slps pembelian petrol rm pertama anda kod rujukan download setel sekarang',
#  'musim sakit macam ni kan agak all hantu jin momok kena tak covid ni tak',
#  'langkah yg dapat di ambil pemerintah dalam mengatasi dampak covid terhadap perekonomian indonesia jawab menjaga konsumsi rumah tangga miskin melalui berbagai program yang dapat dilakukan segera coverage besar dan berdampak langsung ke covid',
#  'mendikbud nadiem makarim mengambil keputusan terkait pencairan dana kip atau kartu indonesia pintar di tengah pandemi virus corona covid',
#  'kadar kematian covid di malaysia masih rendah',
#  'pecah telor sarjana covid',
#  'baru dapet info kalo di gang sebelah rumah di lumajang udah ada yg positif covid semoga seluruh keluarga disana aman',
#  'darurat militer saja pemerintah bias mewajibkan rakyat sebagai serdadu darurat wabah covid dan kesehatan tentu bisa dilakukan untuk mewajibkan para konglomerat untuk keluarkan hartanya untuk kepentingan bersama',
#  'tapi anis ni tak main tiktok dan alhamdulillah tak kena covid',
#  'sbnarnya sudah tdk kaget klo di suruh tinggal rumah sudah terbiasa dri dulu juga social distancing krna ada yg lebih mematikan dalam masyarakat lebih dri covid yaitu kebodohan',
#  'badan pom luncurkan informatorium obat covid bersamaan dengan fgd online tentang penanggulangan covid informatorium ini berisi informasi terkait perkembangan obat covid di dunia dan tata',
#  'revisi kalau tidak ada penambahan jumlah yang positif maka untuk pasien covid dengan gejala penyakit yang parah atau kritis bisa membutuhkan waktu pemulihan klinis sekitar hingga minggu',
#  'syafakallah semoga allah memberi kesembuhan pada dr tun muzamal widan drp wabak covid dan sihat seperti biasa aamiin ya rabbal alamiin',
#  'sambil menunggu orang pintar menemukan obatnya mari waspada tak perlu panik berlebihan faktanya angka kematian bln jauh lebih rendah dr tbc covid tidak menyeramkan',
#  'psbb versus covid',
#  'dirumah aja jaga kesehatan dukung pemerintah memerangi covid dan dirumah ajapun bisa memperoleh investasi dengan untung banyakk dengan didukung legalitas aman dan konsep hotel dan berkelas perputasan',
#  'meditation to fight covid meditasi tidak hanya bermanfaat bagi pikiran tetapi juga bagi tubuh dalam satu kesatuan yang harmonis kehidupan berlangsung dalam cinta yang mengubah segala sesuatu menjadi',
#  'pdhl gak mutlak begitu ya beliau lupa ttg adanya cytokine storm pd pasien covid',
#  'hrap cukup rt nak warna hijau nak bawak kerja merempit musim covid',
#  'salam sapa mana boleh salam salam pqah musim covid ni adoilah',
#  'sebagai bentuk dukungan terhadap tim medis yang tengah berjuang menghadapi dan merawat pasien covid fpi kembali menyalurkan sejumlah bantuan berupa apd serta makanan dan minuman bernutrisi untuk para tim medis',
#  'semoga wabah covid segera berlalu agar lebaran bisa mudik dan berkumpul dgn keluarga',
#  'buat penelitian covid',
#  'tulisan ini saya bikin sekitar minggu lalu br dipublish hari lalu saya nulis ttg konser virtual yg banyak dilakukan saat pandemi covid tp ini jg persiapan utk era nantinya serunya semalam liat postingan jrx di ig menghubungkan konspirasi covid ini dan',
#  'pkp semua orang tak nak rugi semua nya nak bekerja untuk dapatkan duit tapi kena la ingat selagi tak selesai kes covid belum tentu kita semua selamat walaupun kita pergi balik kerja lebih baik rugi sementara daripada menyesal selamanya',
#  'allhumma inn dzu bika minal barashi wal jun bni wal judzmi wa sayy bismillahirrahmanirrahim semoga wabah covid segera berakhir semoga selalu diberikan kesehatan keselamatan serta kebahagiaan di dunia akhirat aamiin',
#  'ketua wantim mui tolak pengalihan dana haji untuk penanganan covid',
#  'ada cara menyuruh covid segera pergi jangan lagi pernah abaikan rumah keluarga dengan terlalu sibuk di luar rumah bukankan covid telah mendidik kita untuk banyak tinggal di dalam rumah bersama keluarga',
#  'kasihan ibu korban covid yg memohon kepada warga video',
#  'bukan karena covid dia hiv',
#  'pandemi covid ketua komisi fatwa mui banten himbau masyarakat tidak ke luar daerah',
#  'update date infografis covid positif sembuh meninggal',
#  'pasien pertama covid di kabupaten serang terdeteksi pulang dari jakarta',
#  'time musim pkp ni pun runner boleh jual dadah ek yg beli dadah pun jenis otak kat mana tah time pkp ni kita nak doa supaya covid ni pulih cepat orang hisap dadah minta mati cepat eh marah plak rasa',
#  'cara allah membersihkan bumi ini dari polusi kendaraan ya adanya covid ini',
#  'teknis rs klaim biaya perawatan pasien covid',
#  'dan terjadi lagi penolakan warga terhadap jenazah perawat yang menangani covid di rsup kariadi semarang lokasi suwakul ungaran video',
#  'wagub sumbar minta data penerima bantuan korban covid tidak duplikasi dan harus detail',
#  'selamat pagi kak siti mina informasikan plasa telkom depok yakni di jl arif rahman hakim no depok saat ini tutup sementara hingga batas waktu yang belum ditentukan mengikuti anjuran dari pemerintah terkait waspada covid dapat diinformasikan keperluannya apa kak',
#  'doa para kiai bawa spirit di tengah pandemi covid via',
#  'pandemi covid kasus dan kematian',
#  'pusing julz rumah lagi rame covid sini rame fwb ga ngotak',
#  'semoga wabah covid segera berlalu dan indonesia kembali baik baik saja amin paling serius',
#  'ada juga lu sbg ketua mutusin utk potong gaji seluruh anggota dpr selama beberapa bulan kedepan utk biaya penanggulangan wabah covid bukannya galang satgas covid utk nyari dana mati kekayaan lo gak lo bawa ke liang lahat',
#  'presiden ri sangat cekatan dalam menghadapi pandemi covid sangat benar sekalib benar sekalic benard benar semuah',
#  'biar hukum yg brjalan yuk fokus lawan covid',
#  'pasca pandemi covid ada orang gila nambah nggak',
#  'sbenarnya ada baiknya covid ni berlaku banyak',
#  'meninggal nya relawan covid kalah tenar dengan glen',
#  'legislatif sosialisasikan bahaya corona hingga ke sawah wakil rakyat di dprd kabupaten kotabaru kalimantan selatan gencar melakukan sosialisasi kepada masyarakat dalam mengantisipasi bahaya penyebaran virus covid yang dimulai dari wilayah perkotaan',
#  'rs darurat wisma atlet kemayoran rawat pasien rumah sakit darurat covid wisma atlet di kemayoran jakarta hingga kamis maret merawat pasien rawat inap yang terdiri atas pria dan perempuan kasdam jaya brigjen tni saleh',
#  'wabah covid merebak perajin masker di badung panen order',
#  'dampak covid terhadap kerjasama internasional jawab adanya kapasitas perawatan kesehatan yang cukup harus terintegrasi antara kebijakan pada bidang kesehatan dan ekonomi makro kerja sama internasional maupun kemitraan lintas batas',
#  'dpc demokrat maluku tengah bagikan masker di pasar binaya kota masohi dan di depan mini market hoky namaelo ini lanjutan dari kegiatan sebelumnya agar kader turun langsung ke masyarakat ujar ketua dpc samuel thiemailattu',
#  'kita putus dulu ya untuk memutuskan mata rantai covid tak cukup dgn jaga jarak saja gunakan masker jika keluar rumah lindungi dirimu karena mungkin saja seseorang disekitar kita terjangkit covid',
#  'dengan diterapkannya psbb pembatasan sosial berskala besar dibebarapa daerah mari refleksikan pengorbanan nya dari rumah masing masing dan kita semua berharap mukjizat segera turun menghalau covid have blessing',
#  'gila serem bgt tante gue abis ngeoprasi org sesaran taunya doi positif covid',
#  'bersama lawan covid polisi_palembang anom_setyadji andes irwan_to sik',
#  'stay safe demi mencergah penyebaran peluasan wabah covid bareng smartfren',
#  'yuk setelah covid berakhir tapi pengen bgt ke argopuro gas',
#  'kenapa harus banget ngikutin berita covid karna di ruang isolasi itu ga enak banget astagfirullah cukup sekali dan semoga virus ini segera lenyap dari bumi',
#  'punten ini rapid test covid kah mas nya',
#  'bali terkini date efek global covid simak selengkapnya pada video saya link youtube',
#  'satu hari dia covid akan pulang ke tempat asalnya tapi smp waktu itu kita harus terus bersabar dan berdoa moga semuanya dipermudahkan ustaz fawwaz',
#  'mau gimana lagi kalo sampe dia bilang masuk tuh covid minta bantuin siapa dia kan memusuhi seluruh dunia bener gak si',
#  'hahaha org yg tak waras disaat sperti inicoba jgn gunakan politik jgn grogoti dulu pemerintah marilah kita sama tumbangkan covid dulu stelah nanti baru kita tumbangkan presiden bukan begitu kan bang memangbetul ssh org yg ambisi kuasa sabarlah',
#  'kbri phnom penh peduli wni dan pencegahan covid',
#  'virus covid menyerang paru paru tapi virus cinta awak menyerang hati saya hehe',
#  'hasil rapid test covid semua ulama di tasimalaya jabar negatif virus corona alhamdulillah semoga allah senantiasa selalu menjaga semua ulama kiyai ustadz ustadzah da pengurus masjid di seluruh indonesia aamiin',
#  'hms itenas bandung melalui satgas covid yayasan wanadri bekerjasama dan bersatu melawan covid dengan upaya penggalangan dana yang akan digunakan untuk membeli sejumlah alat perlengkapan medis di sejumlah rumah sakit di jawa barat',
#  'hms itenas peduli pandemi covid menghadirkan berbagai keprihatinan sosial di seluruh indonesia sudah saatnya kita keluarga besar hms itenas bandung turun tangan memberikan bantuan kemanusiaan ayo berdonasi untuk dukung perlengkapan medis tenaga kesehatan covid',
#  'covid mahasiswa dan pemda andi hasriadi biarkan kami tetap hidup menjadi generasi pelanjut',
#  'antisipasi kemungkinan lain pasien sesak nafas dikebumikan dengan protap pemakaman pdp covid',
#  'selagi vaccine tak jumpa selagi tu bahaya covid ni',
#  'idup udh susah bgt ya tambah covid makin susah perekonomian beneran anjlokk udahann kek pandemi ini',
#  'cegah penyebaran virus covid puk spai fspmi pt nipro indonesia jaya bagikan masker dan hand sanitizer untuk anggota',
#  'kemenkeuri tak bisa dipungkiri aktivitas perekonomian yang kian tertekan akibat covid membuat banyak orang harus kehilangan pekerjaan penghasilan pemerintah telah menyusun strategi untuk',
#  'koruptor bebas karena alasan covid apakah benar ini bukti keberpihakan pemerintah kepada tikus tikus negara hmm simak jawabannya di video ini',
#  'ada cra mnyurh covid sgr prg jngn lgi mlas ke msjd dll bkankh covid tlh mndidk kta bgaimna sdh strssnya kta tnpa ada tmpt mmohn brdoa tk bsa bribdh brjamah shalt di msjd dlm suasna btin yg dmai bgaimna sdhnya mlps sdr kta yg mninggl tnpa dishltkn di msjd',
#  'secara langsung mereka sudah odp harus lakukan treat pada mreka utk dilakukan screening covid',
#  'asrama haji pondok gede siap digunakan untuk ruang isolasi covid',
#  'ada banyak hikmah dari bencana covid salah satunya memperlihatkan bahwa disiplin itu bukan kualitas alamiah manusia tapi memang bentukan dengan paksaan',
#  'kamis malam se dunia mengetuk pintu langit dan munajat doa memohon pada sang khaliq merayu sang maha mendengar meminta sang maha adil untuk keselamatan dunia dari wabah covid nu ku selalu ada tetap ada dan terus ada',
#  'guna memperkecil ruang penyebaran covid kami menghimbau untuk saudaraku dirantauan agar jangan pulang kampung demi keluarga demi indonesia',
#  'hari ini hari jumaat anda rindu solat jumaat mudahan covid ini berlalu pergi mudahan peperangan ini kita menang',
#  'jom amin kan ramai ya allah semoga covid lenyap sebelum ramadhan lindungilah kami semua ya allah assalam',
#  'kemarin ortu gue minta cekkin tunjangan sertifikasi lucky masih lumayan kalau thr batal yaudah asal emang digunakan buat covid biar kehidupan cepat normal gedek lama lama gini terus',
#  'covid lari kencang memburu mangsa adminstrasi psbb jalan di tempat',
#  'lagi tim gugus tugas covid melakukan penyemprotan di kawasan medan bagian utara',
#  'jujur sih udh gapernah ngikutin berita covid bikin pusingg',
#  'heran dengan medsos dan media mainstream yg di angkat kok ojol doang tu banyak yg lebih sengsara kayak buruh bangunan buruh serabutan yg tanpa covid aja hidupnya sudah kacau',
#  'asn tni polri pegawai bumn dilarang mudik kudu manut ora usah ngeyel ayo bersatu semoga covid segera hilang jaga kebersihan jaga kesehatan',
#  'kawasan physical distancing dalam upaya pencegahan covid',
#  'mengalahkan covid',
#  'dua warga kabupaten lampung utara yang dinyatakan positif terpapar covid dikarantina di komplek islamic center kotabumi menurut plt bupati budi utomo yang juga ketua tim gugus tugas penanggulangan covid',
#  'camana nak cari rezeki lebih adakah ada pekerja yg kena buang kerja dgan ekonomi kita yg terganggu sekarang ni disebabkan covid bukannya sekarang masa nak bash atau kecam sana sini pasal isu menteri laa artis laa kaum itu ini buat hal laa',
#  'presiden tidak ada langkah serius hadapi pandemi covid akan menjadi bom waktu bagi semua orang indonesia tidak diyerima di dunia internasional',
#  'yang nolak jenazah covid apalagi kalo itu nakes pada ga takut apa ya jenazah mereka ditolak bumi gapernah nonton sinetron hidayah apa gimana',
#  'posko siaga covid data para pemudik',
#  'planning buat liburan ke sabang batall howalaahh covid covid',
#  'bagi anda korban phk atau dirumahkan akibat penyebaran virus covid yuk daftarkan diri anda untuk mendapatkan kartu pra kerja mudah koq',
#  'bersama bersatu lawan penyebaran virus corona covid jaga kesehatan jauhi kerumunan cuci tangan pakai sabun serta tetap infolingga',
#  'bencana nasional covid satu warga positif corona pemprov ntt koordinasi dengan kemenkes',
#  'hingga saat ini korut mengklaim masih terbebas dari virus covid padahal dua negara yang mengapitnya yakni kosel dan china menjadi episentrum',
#  'kapolrestabes semarang bersama forkopimda kota semarang memberikan himbauan kepada masyarakat untuk memakai masker jaga kebersihan dan tetap di rumah guna memutus mata rantai penyebaran virus corona atau covid',
#  'kalo ga covid hari ini tuh udah nangis di pojokan',
#  'ketularan covid dari pemudik jakarta kota kediri tambah kasus positif',
#  'siapapun yang berpolitik di tengah wabah covid itu tidak peduli rakyat',
#  'bersama bersatu melawan penyebaran virus corona covid di kabupaten lingga jaga kesehatan jauhi kerumunan cuci tangan pakai sabun serta tetap infolingga info',
#  'banyak tanggal merah pas lagi wabah covid',
#  'pejuang covid',
#  'gpp nyai mendingan gitu hibur diri daripada keluar rumah tetap sehat nyai semoga alloh melindungi dan menjauhkan wabah covid utk kita semua aamiin yra',
#  'lebih narapidana bebas di tengah wabah covid termasuk koruptor kebayang ga sih klo kita sudah susah payah menangkap tikus sampai dapat banyak bgt itupun blm semuanya eeehh tau mau dilepaskan kyk apa jadinya rumah kita',
#  'physical distancing memutus rantai penyebaran covid',
#  'seram jatuh tempo massal covid di usa bagaimana dengan indonesia',
#  'repotnya sissy priscillia dampingi anak sekolah sambil bekerja dari rumah selama wabah covid',
#  'tak kenal lelah tim gugus tugas covid kembali semprot pemukiman padat penduduk di belawan',
#  'begitu ntar bnyak yg kena covid si miskin yg dituduh bawa virus ya nasib jadi org miskin ky gw kuli proyek sopir ambulans dan kang gali kubur bakal kena getahnya lindungi kami kaum miskin ya rabb',
#  'berapa banyak bahan kempen dia mahu padam da daripada release padam release padam macam ni lebih baik dok dendiam wat keje yg org tk nampak takyah wat kempen langsung save wang kerajaan boleh masuk tabung covid tolong rakyat',
#  'panduan isolasi mandiri antisipasi penyebaran covid',
#  'betoi tu zmn pkp ni kita spatut bantu nambah beban pulak sb spesis ni la yg angkuh bodoh ni bertambah kes covid ni',
#  'nih aku kasih tips cegah penyebaran berita hoax covid di wa teliti dulu beritanya ya kak jangan asal teruskan',
#  'surabaya babinsa koramil tenggilis mejoyo terus berupaya melaksanakan sosialisasi kepada warga masyarakatnya untuk meredam mewabahnya virus corona atau covid kali ini serma siswono dan sertu supri warsoyo',
#  'virus corona tak mengenal usia pangkat maupun jabatan mereka yang berada di keluarga kerajaan saudi pun tertular covid',
#  'asalamualaikum selamat pagi semua semogga hari ini lebih baik dr hati sebelumnya semogga covid cepat berlalu dan sebelum masuk bulan rohomadhon semgga tidak ada covid lagi amin ya robal alamin',
#  'mudahan semua covid badan mu',
#  'mimpi semalam psbb bertahan hanya beberapa hari dibatalkan karena kasus covid datanya dibuat tampak sudah tidak bertambah tekanan berbagai pihak membuat pemerintah segera menjalankan kegiatan perekonomian seperti sedia kala ahli kesehatan dan tenaga medis hanya bisa pasrah',
#  'dampak covid terhadap perekonomian indonesia jawab kondisi sekarang ini akan berimbas pada menurunnya konsumsi rumah tangga lebih dari itu investasi pun akan merosot tajam maka covid diprediksi investasi akan merosot ke level satu persen atau terburuk',
#  'cegah covid di area physical distancing',
#  'kalo perusahaan baru yang mau bikin efin bagaimana min secara lagi ada wabah covid ini apa ke kantor pajak setempat atau secara online min trmksh',
#  'peta identifikasi sebaran covid di kota serang update per hari ini berdasarkan postingan dinkeskotaserang pasien positif di kota serang bertambah sehingga total menjadi orang hal hal terkait pertanyaan',
#  'semenjak covid ni ramai ke pompuan yg gigih pakai make up keluar rumah dengan mask lagi',
#  'klo sy lebih berduka dgn meninggalnya para petugas medis yg berjibaku mengamankan pasien dari covid',
#  'selamat pagi dapat kami informasikan untuk informasi lengkap jadwal perjalanan krl mulai date bisa di lihat pada website link berikut tks',
#  'covid menyebar ke binatang kah semoga para ahli menelitinya',
#  'semoga indonesia mampu menekan lonjakan pasien covid di tengah tengah minimnya apd',
#  'kepastin ttg kapan miss covid pergi dari muka bumi',
#  'jangan tularkan covid di kampung halaman',
#  'selama pandemik covid polri ungkap angka kejahatan menurun',
#  'mau kesana ngambil sendiri jadi ragu di tambah situasi saat ini yg mengharuskan stay at home karena covid mohon untuk evaluasinya yaa soalnya batas konfirmasi produk dari shopee nya tanggal date ini terima kasih',
#  'polres trenggalek melakukan patroli untuk menghimbau masyarakat untuk jaga jarak karena masih saja ada warga yng suka nongkrong',
#  'orang temenya glenn jangan ikut nyusul dulu biarkan disiksa dulu oleh virus corona covid',
#  'doa saya semoga dunia ini terbebas dari yg namanya virus corona covid agar dunia ini kembali sehat dan manusianya bisa lebih bersyukur kepada allah swt diberikan kesehatan dan kebahagiaan amin',
#  'kampung panglime linting melakukan pencegahan covid virus korona bersama masyarakat',
#  'covid sialan emg',
#  'ramuan empon empon buat jaga kesehatan dimasa virus covid corona jahe bagusnya jahe merah temulawak cengkeh kunir kunyit sereh kayu manis gula merah madu',
#  'pakai masker mainkan yoyo mu potret ini di sd vita school dilakukan sebelum pandemi covid tp budaya menggunakan masker sudah dilakukan contact us cak dolan',
#  'tidak usah cuti laahh kita mengejar ketertinggalan kemarin aja masih belum terkejar belum lagi covid tambah tertinggal lagi jgn malah dijadikan modus',
#  'amit kalau kalian ntar yg pada nolak terus positif covid dan ngga ada yg mau ngerawat kalian kalian bisa apaa',
#  'wahai seluruh perantau yg masih ada di jakarta ingatlah bahwa kita semua adalah odp covid pikirkan baik baik jika kalian ingin memaksakan pulang kampung apapun alasannya jangan sampai hal seperti di gambar ini kalian lakukan',
#  'nama virus ni covid la bukan convic bukan convin adoiii bebal',
#  'cegah virus corona covid srikandi polres pasuruan bagikan masker ke masyarakat',
#  'unggal lilir ngaragap tarang alhamdulillah heunteu panas efek covid',
#  'aliansi bali lawan covid siap bersinergi dengan pemerintah kota denpasar dalam memutus penyebaran covid via mengungkap fakta meluruskan sejarah',
#  'eh ini tl udah kaga sliweran berita covid ud kelar kali ya apa gmna',
#  'pekerja di jatim jadi korban phk karena covid via',
#  'buat masa ni lebih baik tumpukan pada mereka yang terkesan pada musim covid ni',
#  'kemenkeuri pemerintah siapkan kebijakan untuk tangani covid untuk itu belanja negara meningkat untuk fasilitas dan pelayanan kesehatan bantuan sosial dan pemberian stimulus',
#  'nunggu covid beres',
#  'suruh news anchor kalian pake masker lah selain utk melawan covid hal ini jg sbg cara meng edukasi msy yg ngeyel gak mau pakai masker',
#  'awalnya rezim jkw meremehkan menutupi demi amankan turis proyekx investor tka dari negara cina komunis tapi saat indonesia diserang penguasa gagap tidak bisa mencegah mengendalikan lindungi rakyat dari tertular kematian',
#  'bantu tenaga medis rawat pasien covid mata garuda sulsel produksi apd',
#  'new post covid bisakah obat penghilang gumpalan membantu menyelamatkan nyawa pasien dengan ventilator has been published on kafe kepo',
#  'belanja sayur online diserbu warganet saat pandemi covid',
#  'semoga covid segera berakhir aamiin',
#  'gubernur gorontalo rusli habibie mengumumkan kasus positif pertama di gorontalo kamis date malam foto adiwinata solihin',
#  'berita artis meninggal mungkin sengaja di besarkan utk mengalihkan berita atas kelalaian pemerintah mengatasi wabah covid',
#  'dholat berjamaah dilarangngopi diwarung dilarangpesta nikahan dilarang dibubarinada yg mati yag ngelayat sampai penuh kok ngak dilarang dibubarin virus covid madih ada',
#  'kumpulan poster stay at home untuk edukasi covid bagikan lewat facebook whatsapp dan instagram via',
#  'bayani akan yadda zaka zaki gujewa coronavirus covid',
#  'juara pubg ned brotherhood untuk selangor cybergames stay home edition tahniah kepada pemenang nantikan selangor cyber games yang akan berlangsung selepas kita berjaya lawan covid terima kasih juga yg menyumbang semasa kejohanan ini dengan rm berjaya dikutip',
#  'tim pesisir selatan sisir warga pernah kontak dua pasien covid',
#  'ikel covid dan kehidupan sosial bermasyarakat',
#  'ni timbus je dgn salji konfem virus covid tak serang dorang',
#  'cegah penyebaran covid tim satgas periksa setiap kapal yang masuk',
#  'alhamdulillah semoga abang sehat selalu semoga indonesia cepat terbebas dari covid',
#  'indonesia tegaskan perlunya dk pbb tunjukkan kesatuan dlm atasi dampak covid thdp perdamaian keamanan internasional perlu kerja sama global solidaritas hindari diskriminasi serta stigmatisasi',
#  'untuk saat ini merekalah garda terdepan dalam menangani covid ini tunjukan rasa kemanusiaan berpikirlah dengan cerdas',
#  'perawat ini yg ngerawat pasien covid kalau mereka sampai terkena itu sudah resiko pekerjaan mereka nyawa mereka taruhkan demi kesembuhan kalian terus sekarang mau dimakamin di daerahnya malah kalian tolak hatinya nurani kalian tuh pada dimana sih',
#  'jasamu luar biasa tenaga medis yg tlah gugur berjihad di tengah wabah covid',
#  'covid menelanjangi dan mempertontonkan kepada kita bagaimana ini diurus',
#  'dprd kota makassar info_dprd_kotamakassar pemerintah makassar realokasi refocusing anggaran sebesar milyar untuk penanganan dampak pandemi covid di kota makassar ketua dprd kota',
#  'kesan covid merentas pelbagai lapisan iaitu perubatan media dan ideologi politik kini kedengaran analisis geo politik mengenai covid berlegar dalam media mohd azmi abdul hamid',
#  'memperingati milad imam mahdi afs dpw abi sumsel dan dpd abi kab probolinggo giat sosial pencegahan covid lewat',
#  'yah orang seperti anda ini yg kalau dimutasi menjadi virus yg lebih berbahaya dari sekedar covid yang kalau ngomong dikit obat sakit kepala itu bodrex pokoknya harus bodrex padahal ko antokkan kepala kau ke batu itu pun sembuh pak sampek sini paham anda',
#  'alasan kenapa ndak boleh lelarian sepedaan joging bareng di masa pandemik covid',
#  'usahakan jangan menghasut suasana seperti ini apakah tugasmu hanya menghasut seperti ustad ustad kadal gurun kita sebagai warga dunia bukan hanya warga negara harus mendukung usaha menekan covid atau minimal diam',
#  'lebih narapidana bebas di tengah wabah covid termasuk koruptor serba serbi mmc pemerintah melalui kemenkumham telah mengeluarkan dan membebaskan narapidana dan anak melalui program asimilasi dan integrasi berkenaan',
#  'ni orng bagusnye disuru bantu dokter yg nanganin covid tanpa apd sensasi mele lo nesnes',
#  'tiga daerah di papua barat zona hijau dari covid',
#  'semoga covid cepat berlalu',
#  'terapkan dan biasakan jaga jarak untuk cegah merebaknya covid',
#  'walau sudah belum salat jumat insha allah tidak mengurangi yang saya rasakan bersama keluarga dalam melawan covid',
#  'adakah website portal berita media yang memuat timeline kebijakan pemerintah terkait covid',
#  'cegah pagebluk covid polri janji penindakan hukum jalan terakhir',
#  'salah satu penyebab angka kematian karena covid tinggi adalah kemungkinan ada yang bukan meninggal karena covid dinyatakan meninggalnya karena covid karena sakitnya saat covid lagi merebak',
#  'harusnya hari ini aku ke jogja ngajak ibu jalan biar refreshing udh ngerencanain ini dari thn lalup boro jalan di jogja diskitar kediri aja gabisa please covid go away',
#  'semenjak ada covid jam tidur udah kek bukan manusia normal',
#  'update corona covid sulsel jumat date per kabupaten kota maros sidrap postif gowa',
#  'abdul covid vairus kalo cowok siti covida vairus kalo cewek wkwkwkw',
#  'selamat memperingati wafat isa almasih bagi umat kristen dan katholik wafat isa almasih tahun ini jatuh pada hari jumat date semoga di tengah pandemi covid ini selalu diberikan kedamaian dan',
#  'ayok mari kita sama sama lawan covid',
#  'duh gusti masih ada aja ungaran warga menolak pemakaman perawat rsud dr kariadi semarang korban covid',
#  'pembagian sembako serentak kepada warga tidak mampu di sekitar mapolsek dn makoramil terkait dampak wabah corona covid hari kamis tgl date pkl pembagian sembako dilakukankapolsek tawangharjo',
#  'segenap keluarga besar pemerintah kota batu mengucapkan selamat hari jadi kabupaten nganjuk ke semoga kabupaten nganjuk semakin maju dan pandemi covid segera berlalu rebecca_ramona',
#  'rupanya soal persiapan lahan utk kuburan masal korban covid tak hanya pemerintah aceh pemerintah new york pun turut mempersiapkanya sedia payung sebelum hujan',
#  'kenapa perlu duduk di rumah ini sebabnya bersama kita putuskan rantaian jangkitan covid',
#  'vid covid kapan kamu pergi sejak kedatanganmu banyak orang kehilangan',
#  'wabah corona covid peringatan bagi para penguasa agar mereka tidak berbuat makar kepada allah swt dengan menentang penegakan hukum hukum nya cepat atau lambat mereka akan mendapat balasan dari nya',
#  'tugas ekonominama aulia nashwa nathaniano kelas mipa sma negeri banyudonosaya akan menjawab beberapa pertanyaan yang diberikan oleh ibu terkait dengan materi kerjasama internasional isu yang sedang berkembang saat ini covid thread',
#  'bantuan masyarakat terus mengalir rekening gugus tugas covid sudah terisi rp miliaryang bagaimana kabarnya kalau ini beri bohong tolong tangkap sumbernya',
#  'wander luiz masih menunggu hasil dari pemeriksaan tes covid',
#  'kerja kerja termination cable for stand by gen set at pusat kuarantin dan rawatan quarantine for low risk covid patient maeps',
#  'semoga wabah covid segera berlalu',
#  'bisakah permenkes psbb mempercepat penanganan covid',
#  'el asamau mahasiswa lpdp asal alor umumkan positif covid di ntt lewat pos',
#  'berdamailah dlm kesedihn dan rasa sakititulah sumber mata air kehidupan dan kecintaan pada tuhankrna kemuliaan itu hrus kau temui dlm onak dan duri rumi matsnawi jilid bait bgitulah pelajaran ala rumi untk kita di tngah mwbahny covid badai psti berlalu',
#  'flex sangat haritu increase production sekarang baru tahu langit tinggi atau rendah apabila une beast covid datang',
#  'pemerintah larang asn tni polri dan pegawai bumn mudik di tengah pandemi covi',
#  'kata dia nih untuk mencegah virus covid harus rajin mandi perasaan gw semua yg meninggal jg rajin mandi bangun tidur si torus mandi tidak lupa menggosok biji',
#  'mungkin glenn fredly jauh lebih berharga dari pd petugas medis para korban meninggal covid yang bela sungkawa byk bener termasuk dari pemerintah sampai segitunya para petugas medis bersabar ya kami disini yg akan terus mendoakan kalian sepanjang hari demi hari',
#  'yuk kita simak penjelasan dr hastry sp terkait penanganan jenazah covid bersama kita bisaindonesia bisa lawan corona',
#  'dokter tifauzia presiden harusnya sampaikan duka cita ke dokter covid',
#  'covid akan pergi insyaallah kerana masih ada manusia yang rukuk pada allah masih ada bayi yang menyusu dan masih ada burung dan haiwan lain yang mencari makanan untuk terus hidup',
#  'polsek tugu himbau jaga jarak aman cegah covid',
#  'kalau pandemi covid ini berakhir dari bumi ini aku mau nikah dg siapa pokoknya dg laki lakibukan pengangguranbukan buaya sosmedgak harus gantenggak musti kayayg penting matane rak jelalatan ngeliat yg perempuan',
#  'hari ini masuk kali yang keempat kita tidak dapat menunaikan solat jumaat semoga allah menghapuskan covid ini dengan segera amin',
#  'kalau omnibus law tetap berjalan ribuan buruh akan melakukan demo besaran pd tg aprildalam kondisi wabah covid seharusnya dpr lebih fokus menghadapi wabah corona dan korban phk',
#  'personil polsek karanglewas melaksanakan patroli malam blp atau jam malam ciptakan situasi yang kondusif dan adakan cek pos sterilisasi terkait pencegahan penularan covid pada saat jam malam di wilayah kec karanglewas',
#  'berdasarkan survei dari orang yang meninggal karena covid ternyata semuanya karena tidak sembuh',
#  'pembatasan sosial berskala besar psbb di dki jakarta cegah covid berlaku pada date selama pekan sekolah dan tempat kerja diliburkan semua tempat ibadah ditutup semua fasilitas umum',
#  'yup setuju demo dalam skala besar biar kena covid tinggal dibuang kelaut semuanya',
#  'wah konkret instruksi untuk kepala daerah dari kader banteng utk bersatu melawan corona',
#  'putuskan mata rantai covid',
#  'semoga semua frontliner kita terus usaha menyumbang bakti kepada negara',
#  'polres lhokseumawe akan lidik penyebar info dokter positif covid',
#  'karena nasgor mafia udh tutup di malang beres covid gue mau ubek ubek kota malang nyari daging kambing flish bm bgt nasgor kambing dia mau bikin aj kl gx ad udahan dong coronanya huhu',
#  'ntb sudah uii sampel covid kini lebih cepat ketahui hasilnya',
#  'cegah covid hmpi sulsel gelar diskusi daring',
#  'breaking news kabar duka tiga pdp covid kalbar di rsud soedarso meninggal dunia dalam sehari halaman',
#  'fokus tangani covid fokus tangani dampak covid pd buruh saat ini ribuan buruh dirumahkan tnp digaji mrk kehilangan penghasilan',
#  'pak mahfud soal kesehatan dan covid serahkan kpd ahlinya dokter erlina burhan',
#  'selamat pagi rute sudimara tanah abang tersedia pkl time wib untuk informasi lengkap jadwal perjalanan krl mulai date bisa di lihat pada website link berikut tks',
#  'selamat jalan covid selamat datang ramadhan',
#  'makasih mas semoga malaysia juga begitu kita sama perangi covid ini dan semuanya pada patuh ama himbauan pemerintah kita semua',
#  'cegah virus coronamenindaklanjuti maklumat kapolri dan perintah kapolri dalam rangka mencegah dan mengantisipasi penyebaran covid atau virus corona polsek banjarnegara giatkan bersih bersih',
#  'kades tomori bpk anas olabahim himbau warga menunda mudik untuk cegah penyebaran covid',
#  'fix perang dingin akan berlanjutsampe perdebatan masalah covid ini selesaiatausampe lebih dari abis lebaran',
#  'pasca merebak covid nasib tki di malaysia memprihatinkan',
#  'pejuang covid',
#  'ini teh awalnya kl ga salah sakit dbd trs setelah trombosit normal ga ada perbaikan di swab ternyata covid padahal sblmnya ga ada kontak dg covid dr awal sdh pgn drujuk rshs tp penuh katanya',
#  'terbitnya telegram polri yg salah satu poinnya terkait penindakan hukum penghina presiden dan pejabat negara dalam situasi wabah virus corona covid menurut sby mempermalukan indonesia di mata dunia sebab hal seperti itu tak terjadi di negara lain',
#  'pentingnya kita tetap adalah karena kalopun lo kena covid dan sembuh ada kemungkinan virusnya akan aktif lagi',
# ...
#  'amerika egois potret buruknya negara kapitalis tangani covid muslimah talksimak di link berikut',
#  'sore sedulur berikut data terbaru pasien covid di yogyakarta selengkapnya dapat di akses melalui',
#  'covid ada kuliah online ga pernah masuk tugas jarang ngumpul senin uts belom bayarreal life sama',
#  'pt angkasa pura ii persero memberlakukan jam operasional baru di bandara guna optimalisasi layanan dan mendukung pencegahan penyebaran covid selengkapnya',
#  'adun bukit semuja sumbang termometer kepada pusat pemeriksaan virus covid serian',
#  'dari rw di depok kampung siaga covid sudah terbentuk di rw',
#  'luna maya anggap corona covid sebagai ujian dalam hubungannya degan ryochin',
#  'allahh dah ada positive covid dahh kat blok aku nih',
#  'pemerintah pusat melalui gugus tugas percepatan penanggulangan wabah covid nasional mengirimkan bantuan apd alat pelindung diri sebanyak koli pcs dan pcs masker ke sulawesi tenggara sultra',
#  'skrg udh ada lg status otg org tanpa gejala jd risiko kita kontak dgn org byk di rs yg tanpa gejala covid bs lebih tinggi dibandingkan dgn kalian yg ttp',
#  'kembali kepada pangkuan kehidupan islam yakni khilafah adalah kewajiban dan kebutuhan mendesak inilah pesan penting berikutnya bagi indonesia dan dunia',
#  'jumlah pdp covid di kalsel naik pdp meninggal asal batola negatif corona lewat',
#  'solusinya mgkin ada tp mesti kompak ya ama spt saran om faisal basri fokus dl ama covid ampe semua sehat dan pmrintah nemu jalur kordinasi penanganan metode yg tokcer baru mulei lg roda ekonomi trmasuk cipta krja skrg kan masi berantakan smuaa',
#  'tidak tau kenapa sedang malas mendengar berita covid apalagi yang ada hubungannya dengan pemerintah begitu aja',
#  'himbauan wali nagari tandikek kec patamuan kab pd pariaman dalam penanganan covid',
#  'dukung relawan covid alpenland management serahkan bantuan',
#  'tiba dejavu yg aku buat online discussion utk assignment dgn grpmate idk but maybe covid atau bukan kita tetap akan kena kuarintin',
#  'hm tak dapat noti lagi tapi takpelah musim covid pun duit masuk covid tu since awal tahun lagi now dah rmo rd phase still tadek pun kena potong macam hsbc asb pulak dengar percent reits minimum pun dah percent monthly pulaktu nikmat apa lagi yang kau dustakan',
#  'thr pns gaji ke yang terancam sirna dimakan covid dana hutang dipakai utk penanganan virus corona masalahnya hasilnya apa kenapa gaji anggota dpr yg pasti gede tidak juga di potong yaaa',
#  'saya sangat kecewa kepada pihak pln bumn pak katanya menolong meringankan beban biaya listrik pak tertama pelanggan rmh tngga klu yg berkode rm mampu tk dpt discon masalahnya mampu tk mampu disebbkan covid semua rumah tgga terdampak sya pkai watt dan trdmpak covid pak',
#  'penerangan keliling bersatu lawan covid oleh sat lantas polres bone',
#  'as ini diketahui adalah seorang anggota jamaah tabligh yang mengikuti ijtima di kabupaten gowa dan saat ini menjadi cluster baru penyebaran covid karena juga mendatangkan peserta jamaah dari berbagai negara',
#  'kengen banget nonton badminton lagi kangen jantungan nonton badminton kangen teriak ga jls karena lg nonton badminton huhu semoga pandemi covid ini cepat berlalu',
#  'keluar rumah buat cari makan dan banyak yang berubah halte depan rumah yang selalu penuh sekarang nggak ada orang sama sekali proyek gedung yang selalu ramai sekarang sepi langit yang selalu kotor sekarang bersih covid changes everything',
#  'tiga kematian covid hari ini menjadikan jumlah kumulatif kes kematian sebanyak kes',
#  'dalam penanganan pencegahan dan penyebaran virus covid pemerintah memberikan fasilitas pajak untuk alat kesehatan dan pendukungnya apa saja fasilitasnya simak infografis berikut',
#  'buntut pasien positif covid grobogan keluyuran ke sragen pemkab bakal tes semua warga yang sempat kontak di jagongan tanon dan dokter yang menangani',
#  'fraksi partai gerindra dpr ri memberikan bantuan apd dan masker untuk disebarkan kerumah sakit yang didaerah rawan covid seperti dki jakarta jawa barat banten sumut dan sul sel alhamdulilah',
#  'bright side from covid situation uda ga minum dan ngerokok lagi sebulan semoga bs lanjut biasa kalo buka puasa ramadhan bnykan di kantor atau ga bukber sama tmn jrg bgt di rumah smoga covid ilang pas ramadan makes me realize family is the most important things',
#  'kejadian di semarang yang bikin sedih seorang perawat yang ngurus pasien covid meninggal kemudian jenazahnya ditolak tempat oleh warga akhirnya dikembalikan ke rs dapet info langsung dari wali santri yang ibunya juga perawat pasien covid',
#  'menggunakan kajian perubatan berkaitan gunting rambut tapi dalam masa yang sama memperlekehkan kadar infeksi penyebaran covid',
#  'rapid yang ada sekarang mendeteksi antibodi tubuh kita bukan keberadaan virus dalam tubuh kita kalo gejala klinis dan pemeriksaan lab dicurigai covid tapi rapid negatif biasanya akan di rapid ulang hari ke kalo ga salah pemeriksaan yang akurat ya swab tapi ya gitu',
#  'api asmara yang dahulu pernah membara semakin hangat bagai ciuman yang pertama detak jantungku seakan ikut irama karna terlena oleh pesona alunan covid dangdut',
#  'tak hanya sampai disitu saja bawaslu kabupaten magetan juga memberi bantuan sembako dan masker kami harapkan apa yang kita berikan bisa bermanfaat dan membantu mengurangi beban masyarakat yang terdampak wabah covid kata hendrad',
#  'puasa time pkp ni sendu sangat ke sebab tak boleh nak buka kt luar tak dapat pergi bazar tak dapat terawih dekat masjid duduk je lah diam kat rumah kang terkena covid lagi sendu hidup kau tahu tak mengada',
#  'antisipasi penyebaran covid ini arahan gubernur jatim',
#  'rm talian sokongan emosi dan psikososial covid beroperasi setiap hari pagi petang hubungi atau',
#  'tgk betapa mudahnya droplet covid untuk merebak dalam kawasan tertutup peraturan mudah musim covid kalau sakit batuk jangan mengada nak keluar tempat org ramai elakkan dari menyentuh muka semasa berada di luar pakai mask semasa diluar dan cuci tangan',
#  'achmad yurianto tetap menjaga jarak pada saat kontak sosial hindari kerumunan hindari pertemuan pertemuan yang menghadirkan banyak orang ini penting untuk mencegah penularan covid',
#  'sepertinya anak krakatau mengalami gejala covid',
#  'kaya covid aja yg lagi terkenal',
#  'cegah covid dengan tetap di rumah ajah',
#  'mantaaap polda jateng proses tiga pelaku penolak pemakaman jenazah covid sudah kami amankan tiga orang yang diduga memprovokasi warga untuk menolak pemakaman jenazah tersebut',
#  'apa hubungan covid dgn pandemi lainnya apa yang dapat disimpulkan dari peristiwa pandemi yg pernah terjadi di dunia termasuk covid apa hikmah covid yg bisa diambil utk masa mendatang',
#  'sumbang barangan keperluan serta risalah covid',
#  'sehat sehat mas semoga covid ini lekas usai agar ekonomi pulih kembali',
#  'tu kadang suka ketawa ngeliat org indo yg ngetwit dgn nada seolah sg salah kelabakan menangani covid smntr dianya gatau keseharian di sg stay jg di indo yg juga nggak lebih baik dlm penanganan covid tp yaudahlah ya biarin aja kalo bs bikin dia feel better kasian',
#  'di tengah masa darurat covid kua tamalate makassar tetap memberikan layanan menikahkan pasangan suami istri di kantornya',
#  'kerjasama pengadaan obat covid indonesia dengan jepang dan india pusat siaran pers indonesia',
#  'covid anggota kkm positif setakat date',
#  'operasi nyahkuman di sekitar pekan simunjan cegah penularan covid dapatkan berita penuh di fb',
#  'penumpang gelap bernama covid',
#  'patroli dialogis personil polsek palu utara melaksanaka giat patroli himbauan dan bagi selebaran maklumat kapolri tentang bahaya dan cara menangkal penyebaran wabah virus corona atau covid di swalayan pasar dan spbu kegiatan ini rutin dilakukan oleh polsek palu utara',
#  'update tanggal date indonesia mengumumkan orang kasus baru covid total orang dalam perawatan orang sembuh orang meninggal dunia orang',
#  'jokowi pembatasan sosial dan protokol kesehatan yang ketat sudah kita terapkan untuk mengendalikan penyebaran covid sementara untuk mengurangi dampak perekonomian yang mengikutinya pemerintah mengeluarkan paket insentif ekonomi untuk warga',
#  'ada posko covid berdiri di sidoarjo dilengkapi fasilitas alat kesehatan dan apd',
#  'ketika dapet obat methylprednisolone dan cefi ingin rasanya tidak minum itu tapi dokter langsung bilang minumnya de biar cespleng wayahna bisi disangka covid mun gohgoy wae jangan lupa minum air anget kalo bisa akhirnya minum obat dewa dan bom itu',
#  'sobat kukm tahukah anda bahwa rapat anggota koperasi dapat dilaksanakan melalui media online maupun secara tertulis di saat maraknya penyebaran virus covid ini koperasi tetap dapat melaksanakan rat dengan secara',
#  'egois bgm kondisi terkini negara adidaya as stlh diserang virus corona rupanya pmerintah as smkin mmprlihatkan wjh asli sikap egois bgitu nyta ditunjukkan bhkn kpd negara tetangga yg tlh brjasa mnyelamatkannya dr msa sulit akibat pandemi covid',
#  'punya teman yang usahanya terdampak covid dan psbb mungkin ini bisa membantu',
#  'gara gara tiap hari baca berita ttg covid pas mau search lagu kesukaan di google yg terketik secara refleks malah covid mau nge wa temen yg ke ketik malah covid bukannya nama temen gua mau revisi judul artikel lagi refleks ngetik covid covid haunts me',
#  'tolong kuarantin kluster kayangan disini biar malam mimpi kena kusta covid',
#  'yess aku bahkan kmren priksanya ke rs yg nampung pasien covid tp ttep hati sih jaga jarak cuci tangan dst',
#  'komsos babinsa gubeng edukasi warga cegah penyebaran covid',
#  'ketua bawaslu kabupaten magetan hendrad subiyakto mengatakan pihaknya mengadakan bhakti sosial ini dalam rangka ulang tahun bawaslu yang ke dan membangun solidaritas kebangsaan melawan covid atau virus corona',
#  'antisipasi penularan covid polres tanjung balai himbau masyarakat yang masih berkerumun agar kembali kerumah',
#  'ringkasnya positive thinking yang keliru menghadapi covid songolas akibatnya ilusi kontrol ilusi superioritas ilusi kemungkinan',
#  'pasien covid jambi diisolasi apakah keluarga gubernur fu',
#  'grafik perkembangan kasus covid di kabupaten bantul date',
#  'mari bersama kita putus rantai penyebaran virus covid stay home tetap tenang tetap waspada sayangi diri anda dan keluarga anda',
#  'dicurhatin si pasien covid yg lagi jenuh bete karna harus di ruang isolasi mulu idupnya rebahan main hape makan mandi repeat',
#  'anggota komisi ii minta kepala daerah ambil langkah strategis tangani corona covid news',
#  'angka positif covid tembus pemerintah masyarakat belum disiplin',
#  'tapi kalau tersangkut covid mcm mana aku lagi sarankan keluar pakai mask supaya kau tak menyebar dan di sebarkan',
#  'covid ikut memukul perekonomian dan pemerintah pun memberikan stimulus bagi dunia usaha dan industri berapa jumlah umkm di indonesia',
#  'distensif distensif ke kali ini kita akan berdiskusi terkait penangan covid dalam pandangan kesehatan masyarakat dengan narasumber dr irvan afriandi dr grad dipl oeh mph selaku wakil dekan fakultas kedokteran unpad',
#  'apalagi orang yg lebih berbahaya dari covid lurus belok pergi',
#  'salah satu temen ngegame ada yang positif covid aku yakin dia bakal sembuh dan baik baik saja tapi ngerti dia panik dan ketakutan aku langsung sedih',
#  'masa covid ni la kita nak hiburkan orang dengan kebodohan',
#  'pak gubernur trend positif covid di sulsel semakin hari semakin mengkhawatirkan apa lg di daerah bnyk pemudik dr jkt dan mksr kami daerah cemas sekali pak apa lg ada otg pak sebaiknya psbb maki juga kodong cepat ki sblum terlambat kasian',
#  'nkri lawan corona hasil tes swab empat wanita praja ipdn negatif covid',
#  'surat terbuka dokter pdui hrs jd perhatian who kemarin livestreaming katakan jutaan item alat apd telah dikirim ke negara bin malah buka lowongan kerja bagi yg mau jd relawan covid aneh bingung hadapi wabah covid berutang cepat gak bingung iya gak sih',
#  'nanya dong pertama kali covid ada di indonesia kpn ya maret tgl brp gtu',
#  'jika kawalan ketat melalui kebenaran yg diberikan kerajaan kepada sebahagian industri berjaya dilaksanakan tanpa mencetuskan kenaikan mendadak kes positif covid kita mampu menyelamatkan nyawa kedudukan sosio ekonomi rakyat dan kewangan negara',
#  'kami informasikan sebaran kasus covid di kabupaten bantul berdasarkan data dari dinas kesehatan kabupaten bantul per sabtu pukul wib terdapat pasien positif dari kecamatan bambanglipuro yang sembuh',
#  'setelah covid selesai pasti semua akan memudar sedih tapi ya mau bagaimana lagi heuheu',
#  'kalau gak ada covid entah berapa puluh tahun yang akan datang ya dok',
#  'gak heran sih udah bertahun tahun aja masih banyak yg blm paham penularan hiv aids ngejauhin penderitanya karna takut tertular apalagi covid yg baru beberapa bulan ini bukti masyarakat masih sulit dpt informasi yg benar atau emang mereka emang susah dikasih taunya',
#  'saat indonesia berjibaku melawan pandemi covid sungguh sia sia bila seorang yang terbukti ahli dan kaya pengalaman justru berada di penjara',
#  'tapi sejak covid udah hilang di peredaran padahal buat berkebun juga enak terus ga bau meskipun keringetan kayak sarung tangan yg di ace yg harga an tapi emang agak pendek yg ikea',
#  'terima kasih kepada para dokter perawat serta tenaga medis lainnya yang turut membantu dalam memberantas pandemi covid untuk membantu para tenaga medis kalian tetep ya jangan lupa untuk stock yupi kesukaan kalian biar hepi teruss meskipun di rumah ajaaa',
#  'ketua pengarah kesihatan datuk dr noor hisham abdullah berkata pihaknya membuat saringan ke atas penduduk di menara plaza city one dan daripada jumlah itu positif covid',
#  'bagi aku elok je rmo ni fasa ke ni patut diperketatkan lagi tak boleh lah sesetangah industri di buka barber shop lah apa lah tahu semua rugi tapi demi kesihatan demi negara bebas covid kena berkorban',
#  'amerika egois potret buruknya negara kapitalis tangangi covid',
#  'imbas pandemi covid renault liburkan karyawan tim hingga akhir mei',
#  'malam ini nu dan muhammadiyah inggris kaji voluntarisme covid',
#  'corona makin merajalela motivator tung desem waringin positif terinfeksi covid lewat',
#  'benar la yb elok tak kena darah tinggi dari kena covid',
#  'covid aja yg ilang kamu jangan',
#  'covid menyusahkan semuanya',
#  'penerima harus beragama islam lembaga bantuan berbasis agama memangnya tidak mau atau tidak boleh membantu orang susah yang beragama lain sih syarat penerima bantuan covid di bangka belitung harus beragama islam',
#  'ayo kita bersama sama cegah penyebaran covid',
#  'lg covid gini hidup semua susah mau mkn susah cari nafkah juga susah pgn nangis teriak tp ya prcuma mesti sabar dan kuat ada tuhan bersamaku',
#  'yarabbi banyak banget ya berita perawat atau pasien yg postif covid ditolak jenazahnya waktu mau dimakamkan gila jahat bgt ya manusia',
#  'kita sebagai rakyat yang prihatin dan mahukan yang terbaik untuk negara akan ikut pkp utk banteras wabak covid',
#  'apa ini bisa diartikan untuk sembuh dari infeksi covid kita bisa makan tanah dok',
#  'pobia covid mengalahkan pobia mantan para manteman yg gagal move on',
#  'kalo kata temen gue masa covid gini semua anak indigo jadi indihome',
#  'anggota komisi ii minta kepala daerah ambil langkah strategis tangani corona covid',
#  'lama sangat cuti covid ni baik raya terus',
#  'seluruh negara di dunia mengalami masa sulit karena covid rakyat indonesia bersatu bahu membahu mendukung dan mendoakan pemerintah agar nusantara dapat melewati masa sulit ini bukankah agama itu untuk membawa kita kepada kebaikan sadarlah kawan',
#  'setelah covid dan skripsi disaster selesai mau bgt bljr masak lagi terutama bikin kueh',
#  'malam ini projek benda boleh bincang malam di fb persatuan belia harmoni malaysia covid impak terhadap negara ekonomi dan mahasiswa jangan lepaskan peluang ni akhlak khidmat ukhuwah',
#  'pontang panting di koyak covid',
#  'masalahnya sekarang isu jangkitan covid alaaaa bosan laaa jangan laaa sebab barber geng nak buat duit nak menyusahkan dah dah laa tu cukup laaa nama seorang doctor tapi tak leh pikiaq']

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
#
#                                            langkah01  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jum at jum at keempat di kal...
# 7  hikmah di balik musibah covid smg para pejabat...
# 8  cegah covid beserta jajaran polsek kuranji mel...
# 9  ya allah kami memohon pada mu perkenankanlah d...
#
#                                           tokenisasi  \
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jum, at, jum, at, keempa...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...
#
#                                      Tokenisasi_Baku  \
# 0  [cegah, mata, rantai, covid, mari, kita, dirum...
# 1  [aku, mohon, yaallah, semoga, wabah, covid, me...
# 2  [pemprov, papua, naikkan, status, jadi, tangga...
# 3    [covid, belum, nyampe, prigen, mbak, hmm, hoax]
# 4  [nyuruh, orang, pintar, lu, aja, togog, itu, k...
# 5  [pikir, balik, byk, mnde, plk, nk, setelkn, le...
# 6  [selamat, pagi, hari, jum, at, jum, at, keempa...
# 7  [hikmah, di, balik, musibah, covid, smg, para,...
# 8  [cegah, covid, beserta, jajaran, polsek, kuran...
# 9  [ya, allah, kami, memohon, pada, mu, perkenank...
#
#                                          Hasil Ahkir
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog itu kerumunan...
# 5    pikir balik byk mnde plk nk setelkn lepas covid
# 6  selamat pagi hari jum at jum at keempat di kal...
# 7  hikmah di balik musibah covid smg para pejabat...
# 8  cegah covid beserta jajaran polsek kuranji mel...
# 9  ya allah kami memohon pada mu perkenankanlah d...

# %% [markdown]
# # Simpan dataset

# %%
#format csv
df_new.to_csv('clean_dataset_Nicholaus_verdhy.csv',sep=";")

#format xlxs agar mudah terlihat di excel
df_new.to_excel('clean_dataset_Nicholaus_verdhy_12447.xlsx', index=False)

# %% [markdown]
# # Referensi

# %% [markdown]
# [1]	E. J. Rifano, A. C. Fauzan, A. Makhi, E. Nadya, Z. Nasikin, and F. N. Putra, “Text Summarization Menggunakan Library Natural Language Toolkit (NLTK) Berbasis Pemrograman Python,” Ilk. J. Comput. Sci. Appl. Inform., vol. 2, no. 1, Art. no. 1, Apr. 2020, doi: 10.28926/ilkomnika.v2i1.32.
